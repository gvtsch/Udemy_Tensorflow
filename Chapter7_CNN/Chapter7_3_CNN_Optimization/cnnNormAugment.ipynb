# %% [markdown]
# In diesem Skript wird nicht auf ein sequentielles Model (Sequential) gesetzt, sondern auf ein Model

# %%
import os # Arbeiten mit Pfaden
import numpy as np
from typing import Tuple

from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import MaxPooling2D

import matplotlib.pyplot as plt

from mnistData import MNIST
# Out:
# Train size: 60000
# Test size: 10000
# Train shape: (60000, 28, 28, 1)
# Test shape: (10000, 28, 28, 1)
# Min of x_train: 0.0
# Max of x_train: 1.0

# %%
LOGS_DIR = os.path.abspath('C:/Selbststudium/Udemy/Udemy_Tensorflow/logs/aug_and_norm/')
if not os.path.exists(LOGS_DIR):
    os.mkdir(LOGS_DIR)
MODEL_LOG_DIR = os.path.join(LOGS_DIR, 'cnn_norm_augment')

# %%
def build_model(img_shape: Tuple[int, int, int], num_classes: int) -> Model:
    input_img = Input(shape=img_shape)

    x = Conv2D(filters=32, kernel_size=3, padding='same')(input_img)
    x = Activation('relu')(x)
    x = Conv2D(filters=32, kernel_size=3, padding='same')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(filters=64, kernel_size=3, padding='same')(x)
    x = Activation('relu')(x)
    x = Conv2D(filters=64, kernel_size=3, padding='same')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Flatten()(x)
    x = Dense(units=num_classes)(x)
    y_pred = Activation('softmax')(x)

    # Jetzt muss noch ein Modell Objekt mit eben obiger Struktur erstellt werden
    model = Model(
        inputs = [input_img],
        outputs = [y_pred]
    )

    model.summary()

    return model

# %%
data = MNIST(with_normalization=True)
data.data_augmentation(augment_size=5_000)
x_train_, x_val_, y_train_, y_val_ = data.get_splitted_train_validation_set()
model = build_model(data.img_shape, data.num_classes)

model.compile(
    loss='categorical_crossentropy', # wird bei Kategorie-Problemen mit mehr als 2 Klassen genommen
    optimizer=Adam(learning_rate=0.0005),
    metrics=['accuracy']
)

tb_callback = TensorBoard(
    log_dir=MODEL_LOG_DIR,
    write_graph=True
)

model.fit(
    x=x_train_,
    y=y_train_,
    epochs=40,
    batch_size=128,
    verbose=1,
    validation_data=(x_val_, y_val_),
    callbacks=[tb_callback]
)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  activation (Activation)     (None, 28, 28, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        9248
#
#  activation_1 (Activation)   (None, 28, 28, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 64)        18496
#
#  activation_2 (Activation)   (None, 14, 14, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 64)        36928
#
#  activation_3 (Activation)   (None, 14, 14, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 10)                31370
#
#  activation_4 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 96,362
# Trainable params: 96,362
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 341/341 [==============================] - 7s 9ms/step - loss: 0.3470 - accuracy: 0.8939 - val_loss: 0.1142 - val_accuracy: 0.9652
# Epoch 2/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0822 - accuracy: 0.9751 - val_loss: 0.0803 - val_accuracy: 0.9757
# Epoch 3/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0586 - accuracy: 0.9819 - val_loss: 0.0684 - val_accuracy: 0.9807
# Epoch 4/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0441 - accuracy: 0.9865 - val_loss: 0.0625 - val_accuracy: 0.9811
# Epoch 5/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0366 - accuracy: 0.9885 - val_loss: 0.0612 - val_accuracy: 0.9822
# Epoch 6/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0291 - accuracy: 0.9909 - val_loss: 0.0549 - val_accuracy: 0.9841
# Epoch 7/40
# 341/341 [==============================] - 3s 7ms/step - loss: 0.0266 - accuracy: 0.9917 - val_loss: 0.0548 - val_accuracy: 0.9845
# Epoch 8/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0211 - accuracy: 0.9933 - val_loss: 0.0518 - val_accuracy: 0.9862
# Epoch 9/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0187 - accuracy: 0.9939 - val_loss: 0.0569 - val_accuracy: 0.9848
# Epoch 10/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0164 - accuracy: 0.9946 - val_loss: 0.0545 - val_accuracy: 0.9861
# Epoch 11/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0125 - accuracy: 0.9960 - val_loss: 0.0473 - val_accuracy: 0.9877
# Epoch 12/40
# 341/341 [==============================] - 3s 7ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.0638 - val_accuracy: 0.9852
# Epoch 13/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.0606 - val_accuracy: 0.9855
# Epoch 14/40
# 341/341 [==============================] - 3s 7ms/step - loss: 0.0090 - accuracy: 0.9973 - val_loss: 0.0610 - val_accuracy: 0.9871
# Epoch 15/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.0593 - val_accuracy: 0.9877
# Epoch 16/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.0689 - val_accuracy: 0.9858
# Epoch 17/40
# 341/341 [==============================] - 3s 7ms/step - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.0600 - val_accuracy: 0.9878
# Epoch 18/40
# 341/341 [==============================] - 3s 7ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.0572 - val_accuracy: 0.9882
# Epoch 19/40
# 341/341 [==============================] - 3s 7ms/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.0591 - val_accuracy: 0.9881
# Epoch 20/40
# 341/341 [==============================] - 3s 7ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.0694 - val_accuracy: 0.9867
# Epoch 21/40
# 341/341 [==============================] - 3s 7ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.0744 - val_accuracy: 0.9874
# Epoch 22/40
# 341/341 [==============================] - 3s 7ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 0.0664 - val_accuracy: 0.9880
# Epoch 23/40
# 341/341 [==============================] - 3s 7ms/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 0.0775 - val_accuracy: 0.9869
# Epoch 24/40
# 341/341 [==============================] - 3s 7ms/step - loss: 0.0048 - accuracy: 0.9983 - val_loss: 0.0646 - val_accuracy: 0.9883
# Epoch 25/40
# 341/341 [==============================] - 3s 7ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0696 - val_accuracy: 0.9885
# Epoch 26/40
# 341/341 [==============================] - 3s 7ms/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 0.0637 - val_accuracy: 0.9888
# Epoch 27/40
# 341/341 [==============================] - 3s 7ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0664 - val_accuracy: 0.9886
# Epoch 28/40
# 341/341 [==============================] - 3s 7ms/step - loss: 0.0053 - accuracy: 0.9980 - val_loss: 0.0660 - val_accuracy: 0.9876
# Epoch 29/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0685 - val_accuracy: 0.9873
# Epoch 30/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0764 - val_accuracy: 0.9879
# Epoch 31/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0765 - val_accuracy: 0.9879
# Epoch 32/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0712 - val_accuracy: 0.9888
# Epoch 33/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0853 - val_accuracy: 0.9878
# Epoch 34/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.0702 - val_accuracy: 0.9880
# Epoch 35/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.0792 - val_accuracy: 0.9869
# Epoch 36/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 0.0719 - val_accuracy: 0.9894
# Epoch 37/40
# 341/341 [==============================] - 3s 8ms/step - loss: 6.1197e-04 - accuracy: 0.9998 - val_loss: 0.0698 - val_accuracy: 0.9901
# Epoch 38/40
# 341/341 [==============================] - 3s 7ms/step - loss: 8.7329e-05 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 0.9899
# Epoch 39/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0744 - val_accuracy: 0.9888
# Epoch 40/40
# 341/341 [==============================] - 3s 8ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.0730 - val_accuracy: 0.9872
