# %% [markdown]
# In diesem Skript wird nicht auf ein sequentielles Model (Sequential) gesetzt, sondern auf ein Model

# %%
import numpy as np
import tensorflow as tf

from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import MaxPool2D

from sklearn.model_selection import cross_val_score
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

from mnistData import MNIST

# %%
np.random.seed(0)
tf.random.set_seed(0)

# %%
def build_model(
    filters_1: int,
    kernel_size_1: int,
    filters_2: int,
    kernel_size_2: int,
    filters_3: int,
    kernel_size_3: int
) -> Model:
    input_img = Input(shape=(28,28,1))

    x = Conv2D(filters=filters_1, kernel_size=kernel_size_1, padding='same')(input_img)
    x = Activation("relu")(x)
    x = Conv2D(filters=filters_1, kernel_size=kernel_size_1, padding='same')(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)

    x = Conv2D(filters=filters_2, kernel_size=kernel_size_2, padding='same')(input_img)
    x = Activation('relu')(x)
    x = Conv2D(filters=filters_2, kernel_size=kernel_size_2, padding='same')(x)
    x = Activation('relu')(x)
    x = MaxPool2D()(x)

    x = Conv2D(filters=filters_3, kernel_size=kernel_size_3, padding='same')(x)
    x = Activation('relu')(x)
    x = Conv2D(filters=filters_3, kernel_size=kernel_size_3, padding='same')(x)
    x = Activation('relu')(x)
    x = MaxPool2D()(x)

    x = Flatten()(x)
    x = Dense(units=128)(x)
    x = Activation("relu")(x)
    x = Dense(units=10)(x)
    y_pred = Activation("softmax")(x)

    model = Model(
        inputs = [input_img],
        outputs = [y_pred]
    )

    model.compile( 
        loss='categorical_crossentropy',
        optimizer='Adam',
        metrics=['accuracy']
    )
    
    model.summary()

    return model

# %%
data = MNIST(with_normalization=True)
x_train, y_train = data.get_train_set()

param_distributions = {
    # Bei einer Random Search gibt man eine Zufallsverteilung an in der gesamplet wird
    'filters_1': randint(8, 64),
    'kernel_size_1': randint(3, 8),
    'filters_2': randint(8, 64),
    'kernel_size_2': randint(3, 8),
    'filters_3': randint(8, 64),
    'kernel_size_3': randint(3, 8)
}

keras_clf = KerasClassifier(
    build_fn=build_model, # Funktionsobjekt übergeben, Fit-Methode ist hier intern gelöst und Parameter müssen angegeben werden
    epochs=3,
    batch_size=128,
    verbose=1
)

rand_cv = RandomizedSearchCV(
    estimator=keras_clf,
    param_distributions=param_distributions,
    n_iter=10,
    n_jobs=1,
    verbose=0,
    cv=3
)

rand_result = rand_cv.fit(
    X=x_train,
    y=y_train
)
# Out:
# C:\Users\gutsc\AppData\Local\Temp/ipykernel_27460/2244875532.py:14: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead.
#   keras_clf = KerasClassifier(
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 55)        2035
#
#  activation_2 (Activation)   (None, 28, 28, 55)        0
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 55)        108955
#
#  activation_3 (Activation)   (None, 28, 28, 55)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 55)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 61)        120841
#
#  activation_4 (Activation)   (None, 14, 14, 61)        0
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 61)        134017
#
#  activation_5 (Activation)   (None, 14, 14, 61)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 7, 7, 61)         0
#  2D)
#
#  flatten (Flatten)           (None, 2989)              0
#
#  dense (Dense)               (None, 128)               382720
#
#  activation_6 (Activation)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
#  activation_7 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 749,858
# Trainable params: 749,858
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 10s 20ms/step - loss: 0.1810 - accuracy: 0.9419
# Epoch 2/3
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0465 - accuracy: 0.9858
# Epoch 3/3
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0314 - accuracy: 0.9904
# 157/157 [==============================] - 1s 8ms/step - loss: 0.0361 - accuracy: 0.9900
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 55)        2035
#
#  activation_10 (Activation)  (None, 28, 28, 55)        0
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 55)        108955
#
#  activation_11 (Activation)  (None, 28, 28, 55)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 14, 14, 55)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 61)        120841
#
#  activation_12 (Activation)  (None, 14, 14, 61)        0
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 61)        134017
#
#  activation_13 (Activation)  (None, 14, 14, 61)        0
#
#  max_pooling2d_5 (MaxPooling  (None, 7, 7, 61)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 2989)              0
#
#  dense_2 (Dense)             (None, 128)               382720
#
#  activation_14 (Activation)  (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
#  activation_15 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 749,858
# Trainable params: 749,858
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 6s 19ms/step - loss: 0.1909 - accuracy: 0.9390
# Epoch 2/3
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0467 - accuracy: 0.9855
# Epoch 3/3
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0330 - accuracy: 0.9894
# 157/157 [==============================] - 1s 7ms/step - loss: 0.0508 - accuracy: 0.9868
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_14 (Conv2D)          (None, 28, 28, 55)        2035
#
#  activation_18 (Activation)  (None, 28, 28, 55)        0
#
#  conv2d_15 (Conv2D)          (None, 28, 28, 55)        108955
#
#  activation_19 (Activation)  (None, 28, 28, 55)        0
#
#  max_pooling2d_7 (MaxPooling  (None, 14, 14, 55)       0
#  2D)
#
#  conv2d_16 (Conv2D)          (None, 14, 14, 61)        120841
#
#  activation_20 (Activation)  (None, 14, 14, 61)        0
#
#  conv2d_17 (Conv2D)          (None, 14, 14, 61)        134017
#
#  activation_21 (Activation)  (None, 14, 14, 61)        0
#
#  max_pooling2d_8 (MaxPooling  (None, 7, 7, 61)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 2989)              0
#
#  dense_4 (Dense)             (None, 128)               382720
#
#  activation_22 (Activation)  (None, 128)               0
#
#  dense_5 (Dense)             (None, 10)                1290
#
#  activation_23 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 749,858
# Trainable params: 749,858
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 7s 20ms/step - loss: 0.1867 - accuracy: 0.9413
# Epoch 2/3
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0469 - accuracy: 0.9851
# Epoch 3/3
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0298 - accuracy: 0.9912
# 157/157 [==============================] - 1s 7ms/step - loss: 0.0393 - accuracy: 0.9878
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_20 (Conv2D)          (None, 28, 28, 47)        1222
#
#  activation_26 (Activation)  (None, 28, 28, 47)        0
#
#  conv2d_21 (Conv2D)          (None, 28, 28, 47)        55272
#
#  activation_27 (Activation)  (None, 28, 28, 47)        0
#
#  max_pooling2d_10 (MaxPoolin  (None, 14, 14, 47)       0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 17)        39168
#
#  activation_28 (Activation)  (None, 14, 14, 17)        0
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 17)        14178
#
#  activation_29 (Activation)  (None, 14, 14, 17)        0
#
#  max_pooling2d_11 (MaxPoolin  (None, 7, 7, 17)         0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 833)               0
#
#  dense_6 (Dense)             (None, 128)               106752
#
#  activation_30 (Activation)  (None, 128)               0
#
#  dense_7 (Dense)             (None, 10)                1290
#
#  activation_31 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 217,882
# Trainable params: 217,882
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.2305 - accuracy: 0.9270
# Epoch 2/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0565 - accuracy: 0.9826
# Epoch 3/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0372 - accuracy: 0.9880
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0460 - accuracy: 0.9862
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_26 (Conv2D)          (None, 28, 28, 47)        1222
#
#  activation_34 (Activation)  (None, 28, 28, 47)        0
#
#  conv2d_27 (Conv2D)          (None, 28, 28, 47)        55272
#
#  activation_35 (Activation)  (None, 28, 28, 47)        0
#
#  max_pooling2d_13 (MaxPoolin  (None, 14, 14, 47)       0
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 14, 14, 17)        39168
#
#  activation_36 (Activation)  (None, 14, 14, 17)        0
#
#  conv2d_29 (Conv2D)          (None, 14, 14, 17)        14178
#
#  activation_37 (Activation)  (None, 14, 14, 17)        0
#
#  max_pooling2d_14 (MaxPoolin  (None, 7, 7, 17)         0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 833)               0
#
#  dense_8 (Dense)             (None, 128)               106752
#
#  activation_38 (Activation)  (None, 128)               0
#
#  dense_9 (Dense)             (None, 10)                1290
#
#  activation_39 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 217,882
# Trainable params: 217,882
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.2258 - accuracy: 0.9285
# Epoch 2/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0551 - accuracy: 0.9828
# Epoch 3/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0386 - accuracy: 0.9882
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0628 - accuracy: 0.9817
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_32 (Conv2D)          (None, 28, 28, 47)        1222
#
#  activation_42 (Activation)  (None, 28, 28, 47)        0
#
#  conv2d_33 (Conv2D)          (None, 28, 28, 47)        55272
#
#  activation_43 (Activation)  (None, 28, 28, 47)        0
#
#  max_pooling2d_16 (MaxPoolin  (None, 14, 14, 47)       0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 14, 14, 17)        39168
#
#  activation_44 (Activation)  (None, 14, 14, 17)        0
#
#  conv2d_35 (Conv2D)          (None, 14, 14, 17)        14178
#
#  activation_45 (Activation)  (None, 14, 14, 17)        0
#
#  max_pooling2d_17 (MaxPoolin  (None, 7, 7, 17)         0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 833)               0
#
#  dense_10 (Dense)            (None, 128)               106752
#
#  activation_46 (Activation)  (None, 128)               0
#
#  dense_11 (Dense)            (None, 10)                1290
#
#  activation_47 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 217,882
# Trainable params: 217,882
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.2184 - accuracy: 0.9329
# Epoch 2/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0521 - accuracy: 0.9844
# Epoch 3/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0347 - accuracy: 0.9888
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0441 - accuracy: 0.9869
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_38 (Conv2D)          (None, 28, 28, 14)        700
#
#  activation_50 (Activation)  (None, 28, 28, 14)        0
#
#  conv2d_39 (Conv2D)          (None, 28, 28, 14)        9618
#
#  activation_51 (Activation)  (None, 28, 28, 14)        0
#
#  max_pooling2d_19 (MaxPoolin  (None, 14, 14, 14)       0
#  g2D)
#
#  conv2d_40 (Conv2D)          (None, 14, 14, 32)        11232
#
#  activation_52 (Activation)  (None, 14, 14, 32)        0
#
#  conv2d_41 (Conv2D)          (None, 14, 14, 32)        25632
#
#  activation_53 (Activation)  (None, 14, 14, 32)        0
#
#  max_pooling2d_20 (MaxPoolin  (None, 7, 7, 32)         0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 1568)              0
#
#  dense_12 (Dense)            (None, 128)               200832
#
#  activation_54 (Activation)  (None, 128)               0
#
#  dense_13 (Dense)            (None, 10)                1290
#
#  activation_55 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 249,304
# Trainable params: 249,304
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.2545 - accuracy: 0.9206
# Epoch 2/3
# 313/313 [==============================] - 2s 8ms/step - loss: 0.0592 - accuracy: 0.9819
# Epoch 3/3
# 313/313 [==============================] - 2s 8ms/step - loss: 0.0410 - accuracy: 0.9876
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0395 - accuracy: 0.9877
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_44 (Conv2D)          (None, 28, 28, 14)        700
#
#  activation_58 (Activation)  (None, 28, 28, 14)        0
#
#  conv2d_45 (Conv2D)          (None, 28, 28, 14)        9618
#
#  activation_59 (Activation)  (None, 28, 28, 14)        0
#
#  max_pooling2d_22 (MaxPoolin  (None, 14, 14, 14)       0
#  g2D)
#
#  conv2d_46 (Conv2D)          (None, 14, 14, 32)        11232
#
#  activation_60 (Activation)  (None, 14, 14, 32)        0
#
#  conv2d_47 (Conv2D)          (None, 14, 14, 32)        25632
#
#  activation_61 (Activation)  (None, 14, 14, 32)        0
#
#  max_pooling2d_23 (MaxPoolin  (None, 7, 7, 32)         0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 1568)              0
#
#  dense_14 (Dense)            (None, 128)               200832
#
#  activation_62 (Activation)  (None, 128)               0
#
#  dense_15 (Dense)            (None, 10)                1290
#
#  activation_63 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 249,304
# Trainable params: 249,304
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.2551 - accuracy: 0.9197
# Epoch 2/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0601 - accuracy: 0.9814
# Epoch 3/3
# 313/313 [==============================] - 2s 8ms/step - loss: 0.0430 - accuracy: 0.9866
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0478 - accuracy: 0.9861
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_50 (Conv2D)          (None, 28, 28, 14)        700
#
#  activation_66 (Activation)  (None, 28, 28, 14)        0
#
#  conv2d_51 (Conv2D)          (None, 28, 28, 14)        9618
#
#  activation_67 (Activation)  (None, 28, 28, 14)        0
#
#  max_pooling2d_25 (MaxPoolin  (None, 14, 14, 14)       0
#  g2D)
#
#  conv2d_52 (Conv2D)          (None, 14, 14, 32)        11232
#
#  activation_68 (Activation)  (None, 14, 14, 32)        0
#
#  conv2d_53 (Conv2D)          (None, 14, 14, 32)        25632
#
#  activation_69 (Activation)  (None, 14, 14, 32)        0
#
#  max_pooling2d_26 (MaxPoolin  (None, 7, 7, 32)         0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 1568)              0
#
#  dense_16 (Dense)            (None, 128)               200832
#
#  activation_70 (Activation)  (None, 128)               0
#
#  dense_17 (Dense)            (None, 10)                1290
#
#  activation_71 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 249,304
# Trainable params: 249,304
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.2481 - accuracy: 0.9207
# Epoch 2/3
# 313/313 [==============================] - 2s 8ms/step - loss: 0.0612 - accuracy: 0.9811
# Epoch 3/3
# 313/313 [==============================] - 2s 8ms/step - loss: 0.0406 - accuracy: 0.9875
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0429 - accuracy: 0.9873
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_56 (Conv2D)          (None, 28, 28, 46)        782
#
#  activation_74 (Activation)  (None, 28, 28, 46)        0
#
#  conv2d_57 (Conv2D)          (None, 28, 28, 46)        33902
#
#  activation_75 (Activation)  (None, 28, 28, 46)        0
#
#  max_pooling2d_28 (MaxPoolin  (None, 14, 14, 46)       0
#  g2D)
#
#  conv2d_58 (Conv2D)          (None, 14, 14, 47)        34639
#
#  activation_76 (Activation)  (None, 14, 14, 47)        0
#
#  conv2d_59 (Conv2D)          (None, 14, 14, 47)        35391
#
#  activation_77 (Activation)  (None, 14, 14, 47)        0
#
#  max_pooling2d_29 (MaxPoolin  (None, 7, 7, 47)         0
#  g2D)
#
#  flatten_9 (Flatten)         (None, 2303)              0
#
#  dense_18 (Dense)            (None, 128)               294912
#
#  activation_78 (Activation)  (None, 128)               0
#
#  dense_19 (Dense)            (None, 10)                1290
#
#  activation_79 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 400,916
# Trainable params: 400,916
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 4s 11ms/step - loss: 0.2113 - accuracy: 0.9336
# Epoch 2/3
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0504 - accuracy: 0.9839
# Epoch 3/3
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0338 - accuracy: 0.9894
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0421 - accuracy: 0.9881
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_62 (Conv2D)          (None, 28, 28, 46)        782
#
#  activation_82 (Activation)  (None, 28, 28, 46)        0
#
#  conv2d_63 (Conv2D)          (None, 28, 28, 46)        33902
#
#  activation_83 (Activation)  (None, 28, 28, 46)        0
#
#  max_pooling2d_31 (MaxPoolin  (None, 14, 14, 46)       0
#  g2D)
#
#  conv2d_64 (Conv2D)          (None, 14, 14, 47)        34639
#
#  activation_84 (Activation)  (None, 14, 14, 47)        0
#
#  conv2d_65 (Conv2D)          (None, 14, 14, 47)        35391
#
#  activation_85 (Activation)  (None, 14, 14, 47)        0
#
#  max_pooling2d_32 (MaxPoolin  (None, 7, 7, 47)         0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 2303)              0
#
#  dense_20 (Dense)            (None, 128)               294912
#
#  activation_86 (Activation)  (None, 128)               0
#
#  dense_21 (Dense)            (None, 10)                1290
#
#  activation_87 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 400,916
# Trainable params: 400,916
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 4s 10ms/step - loss: 0.2202 - accuracy: 0.9275
# Epoch 2/3
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0507 - accuracy: 0.9842
# Epoch 3/3
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0358 - accuracy: 0.9886
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0472 - accuracy: 0.9865
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_68 (Conv2D)          (None, 28, 28, 46)        782
#
#  activation_90 (Activation)  (None, 28, 28, 46)        0
#
#  conv2d_69 (Conv2D)          (None, 28, 28, 46)        33902
#
#  activation_91 (Activation)  (None, 28, 28, 46)        0
#
#  max_pooling2d_34 (MaxPoolin  (None, 14, 14, 46)       0
#  g2D)
#
#  conv2d_70 (Conv2D)          (None, 14, 14, 47)        34639
#
#  activation_92 (Activation)  (None, 14, 14, 47)        0
#
#  conv2d_71 (Conv2D)          (None, 14, 14, 47)        35391
#
#  activation_93 (Activation)  (None, 14, 14, 47)        0
#
#  max_pooling2d_35 (MaxPoolin  (None, 7, 7, 47)         0
#  g2D)
#
#  flatten_11 (Flatten)        (None, 2303)              0
#
#  dense_22 (Dense)            (None, 128)               294912
#
#  activation_94 (Activation)  (None, 128)               0
#
#  dense_23 (Dense)            (None, 10)                1290
#
#  activation_95 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 400,916
# Trainable params: 400,916
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 4s 10ms/step - loss: 0.2093 - accuracy: 0.9360
# Epoch 2/3
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0514 - accuracy: 0.9843
# Epoch 3/3
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0326 - accuracy: 0.9896
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0405 - accuracy: 0.9876
# Model: "model_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_74 (Conv2D)          (None, 28, 28, 16)        592
#
#  activation_98 (Activation)  (None, 28, 28, 16)        0
#
#  conv2d_75 (Conv2D)          (None, 28, 28, 16)        9232
#
#  activation_99 (Activation)  (None, 28, 28, 16)        0
#
#  max_pooling2d_37 (MaxPoolin  (None, 14, 14, 16)       0
#  g2D)
#
#  conv2d_76 (Conv2D)          (None, 14, 14, 17)        2465
#
#  activation_100 (Activation)  (None, 14, 14, 17)       0
#
#  conv2d_77 (Conv2D)          (None, 14, 14, 17)        2618
#
#  activation_101 (Activation)  (None, 14, 14, 17)       0
#
#  max_pooling2d_38 (MaxPoolin  (None, 7, 7, 17)         0
#  g2D)
#
#  flatten_12 (Flatten)        (None, 833)               0
#
#  dense_24 (Dense)            (None, 128)               106752
#
#  activation_102 (Activation)  (None, 128)              0
#
#  dense_25 (Dense)            (None, 10)                1290
#
#  activation_103 (Activation)  (None, 10)               0
#
# =================================================================
# Total params: 122,949
# Trainable params: 122,949
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 3s 7ms/step - loss: 0.3058 - accuracy: 0.9028
# Epoch 2/3
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0791 - accuracy: 0.9754
# Epoch 3/3
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0544 - accuracy: 0.9825
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0618 - accuracy: 0.9809
# Model: "model_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_80 (Conv2D)          (None, 28, 28, 16)        592
#
#  activation_106 (Activation)  (None, 28, 28, 16)       0
#
#  conv2d_81 (Conv2D)          (None, 28, 28, 16)        9232
#
#  activation_107 (Activation)  (None, 28, 28, 16)       0
#
#  max_pooling2d_40 (MaxPoolin  (None, 14, 14, 16)       0
#  g2D)
#
#  conv2d_82 (Conv2D)          (None, 14, 14, 17)        2465
#
#  activation_108 (Activation)  (None, 14, 14, 17)       0
#
#  conv2d_83 (Conv2D)          (None, 14, 14, 17)        2618
#
#  activation_109 (Activation)  (None, 14, 14, 17)       0
#
#  max_pooling2d_41 (MaxPoolin  (None, 7, 7, 17)         0
#  g2D)
#
#  flatten_13 (Flatten)        (None, 833)               0
#
#  dense_26 (Dense)            (None, 128)               106752
#
#  activation_110 (Activation)  (None, 128)              0
#
#  dense_27 (Dense)            (None, 10)                1290
#
#  activation_111 (Activation)  (None, 10)               0
#
# =================================================================
# Total params: 122,949
# Trainable params: 122,949
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 2s 7ms/step - loss: 0.2827 - accuracy: 0.9114
# Epoch 2/3
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0741 - accuracy: 0.9772
# Epoch 3/3
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0523 - accuracy: 0.9837
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0587 - accuracy: 0.9833
# Model: "model_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_15 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_86 (Conv2D)          (None, 28, 28, 16)        592
#
#  activation_114 (Activation)  (None, 28, 28, 16)       0
#
#  conv2d_87 (Conv2D)          (None, 28, 28, 16)        9232
#
#  activation_115 (Activation)  (None, 28, 28, 16)       0
#
#  max_pooling2d_43 (MaxPoolin  (None, 14, 14, 16)       0
#  g2D)
#
#  conv2d_88 (Conv2D)          (None, 14, 14, 17)        2465
#
#  activation_116 (Activation)  (None, 14, 14, 17)       0
#
#  conv2d_89 (Conv2D)          (None, 14, 14, 17)        2618
#
#  activation_117 (Activation)  (None, 14, 14, 17)       0
#
#  max_pooling2d_44 (MaxPoolin  (None, 7, 7, 17)         0
#  g2D)
#
#  flatten_14 (Flatten)        (None, 833)               0
#
#  dense_28 (Dense)            (None, 128)               106752
#
#  activation_118 (Activation)  (None, 128)              0
#
#  dense_29 (Dense)            (None, 10)                1290
#
#  activation_119 (Activation)  (None, 10)               0
#
# =================================================================
# Total params: 122,949
# Trainable params: 122,949
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 2s 7ms/step - loss: 0.2728 - accuracy: 0.9173
# Epoch 2/3
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0716 - accuracy: 0.9783
# Epoch 3/3
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0511 - accuracy: 0.9850
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0590 - accuracy: 0.9824
# Model: "model_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_16 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_92 (Conv2D)          (None, 28, 28, 13)        338
#
#  activation_122 (Activation)  (None, 28, 28, 13)       0
#
#  conv2d_93 (Conv2D)          (None, 28, 28, 13)        4238
#
#  activation_123 (Activation)  (None, 28, 28, 13)       0
#
#  max_pooling2d_46 (MaxPoolin  (None, 14, 14, 13)       0
#  g2D)
#
#  conv2d_94 (Conv2D)          (None, 14, 14, 23)        10787
#
#  activation_124 (Activation)  (None, 14, 14, 23)       0
#
#  conv2d_95 (Conv2D)          (None, 14, 14, 23)        19067
#
#  activation_125 (Activation)  (None, 14, 14, 23)       0
#
#  max_pooling2d_47 (MaxPoolin  (None, 7, 7, 23)         0
#  g2D)
#
#  flatten_15 (Flatten)        (None, 1127)              0
#
#  dense_30 (Dense)            (None, 128)               144384
# ...
#
#  activation_207 (Activation)  (None, 10)               0
#
# =================================================================
# Total params: 550,953
# Trainable params: 550,953
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1958 - accuracy: 0.9376
# Epoch 2/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0487 - accuracy: 0.9853
# Epoch 3/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0357 - accuracy: 0.9887
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0443 - accuracy: 0.9873
# Model: "model_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_27 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_158 (Conv2D)         (None, 28, 28, 58)        1508
#
#  activation_210 (Activation)  (None, 28, 28, 58)       0
#
#  conv2d_159 (Conv2D)         (None, 28, 28, 58)        84158
#
#  activation_211 (Activation)  (None, 28, 28, 58)       0
#
#  max_pooling2d_79 (MaxPoolin  (None, 14, 14, 58)       0
#  g2D)
#
#  conv2d_160 (Conv2D)         (None, 14, 14, 63)        32949
#
#  activation_212 (Activation)  (None, 14, 14, 63)       0
#
#  conv2d_161 (Conv2D)         (None, 14, 14, 63)        35784
#
#  activation_213 (Activation)  (None, 14, 14, 63)       0
#
#  max_pooling2d_80 (MaxPoolin  (None, 7, 7, 63)         0
#  g2D)
#
#  flatten_26 (Flatten)        (None, 3087)              0
#
#  dense_52 (Dense)            (None, 128)               395264
#
#  activation_214 (Activation)  (None, 128)              0
#
#  dense_53 (Dense)            (None, 10)                1290
#
#  activation_215 (Activation)  (None, 10)               0
#
# =================================================================
# Total params: 550,953
# Trainable params: 550,953
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1943 - accuracy: 0.9387
# Epoch 2/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0491 - accuracy: 0.9844
# Epoch 3/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0331 - accuracy: 0.9901
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0519 - accuracy: 0.9840
# Model: "model_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_28 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_164 (Conv2D)         (None, 28, 28, 44)        2200
#
#  activation_218 (Activation)  (None, 28, 28, 44)       0
#
#  conv2d_165 (Conv2D)         (None, 28, 28, 44)        94908
#
#  activation_219 (Activation)  (None, 28, 28, 44)       0
#
#  max_pooling2d_82 (MaxPoolin  (None, 14, 14, 44)       0
#  g2D)
#
#  conv2d_166 (Conv2D)         (None, 14, 14, 61)        43005
#
#  activation_220 (Activation)  (None, 14, 14, 61)       0
#
#  conv2d_167 (Conv2D)         (None, 14, 14, 61)        59597
#
#  activation_221 (Activation)  (None, 14, 14, 61)       0
#
#  max_pooling2d_83 (MaxPoolin  (None, 7, 7, 61)         0
#  g2D)
#
#  flatten_27 (Flatten)        (None, 2989)              0
#
#  dense_54 (Dense)            (None, 128)               382720
#
#  activation_222 (Activation)  (None, 128)              0
#
#  dense_55 (Dense)            (None, 10)                1290
#
#  activation_223 (Activation)  (None, 10)               0
#
# =================================================================
# Total params: 583,720
# Trainable params: 583,720
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 6s 16ms/step - loss: 0.2031 - accuracy: 0.9352
# Epoch 2/3
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0524 - accuracy: 0.9841
# Epoch 3/3
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0358 - accuracy: 0.9888
# 157/157 [==============================] - 1s 7ms/step - loss: 0.0471 - accuracy: 0.9869
# Model: "model_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_29 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_170 (Conv2D)         (None, 28, 28, 44)        2200
#
#  activation_226 (Activation)  (None, 28, 28, 44)       0
#
#  conv2d_171 (Conv2D)         (None, 28, 28, 44)        94908
#
#  activation_227 (Activation)  (None, 28, 28, 44)       0
#
#  max_pooling2d_85 (MaxPoolin  (None, 14, 14, 44)       0
#  g2D)
#
#  conv2d_172 (Conv2D)         (None, 14, 14, 61)        43005
#
#  activation_228 (Activation)  (None, 14, 14, 61)       0
#
#  conv2d_173 (Conv2D)         (None, 14, 14, 61)        59597
#
#  activation_229 (Activation)  (None, 14, 14, 61)       0
#
#  max_pooling2d_86 (MaxPoolin  (None, 7, 7, 61)         0
#  g2D)
#
#  flatten_28 (Flatten)        (None, 2989)              0
#
#  dense_56 (Dense)            (None, 128)               382720
#
#  activation_230 (Activation)  (None, 128)              0
#
#  dense_57 (Dense)            (None, 10)                1290
#
#  activation_231 (Activation)  (None, 10)               0
#
# =================================================================
# Total params: 583,720
# Trainable params: 583,720
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 5s 16ms/step - loss: 0.1984 - accuracy: 0.9353
# Epoch 2/3
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0491 - accuracy: 0.9848
# Epoch 3/3
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0339 - accuracy: 0.9896
# 157/157 [==============================] - 1s 6ms/step - loss: 0.0422 - accuracy: 0.9882
# Model: "model_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_30 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_176 (Conv2D)         (None, 28, 28, 44)        2200
#
#  activation_234 (Activation)  (None, 28, 28, 44)       0
#
#  conv2d_177 (Conv2D)         (None, 28, 28, 44)        94908
#
#  activation_235 (Activation)  (None, 28, 28, 44)       0
#
#  max_pooling2d_88 (MaxPoolin  (None, 14, 14, 44)       0
#  g2D)
#
#  conv2d_178 (Conv2D)         (None, 14, 14, 61)        43005
#
#  activation_236 (Activation)  (None, 14, 14, 61)       0
#
#  conv2d_179 (Conv2D)         (None, 14, 14, 61)        59597
#
#  activation_237 (Activation)  (None, 14, 14, 61)       0
#
#  max_pooling2d_89 (MaxPoolin  (None, 7, 7, 61)         0
#  g2D)
#
#  flatten_29 (Flatten)        (None, 2989)              0
#
#  dense_58 (Dense)            (None, 128)               382720
#
#  activation_238 (Activation)  (None, 128)              0
#
#  dense_59 (Dense)            (None, 10)                1290
#
#  activation_239 (Activation)  (None, 10)               0
#
# =================================================================
# Total params: 583,720
# Trainable params: 583,720
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 5s 16ms/step - loss: 0.1930 - accuracy: 0.9375
# Epoch 2/3
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0517 - accuracy: 0.9844
# Epoch 3/3
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0339 - accuracy: 0.9898
# 157/157 [==============================] - 1s 6ms/step - loss: 0.0447 - accuracy: 0.9864
# Model: "model_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_31 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_182 (Conv2D)         (None, 28, 28, 55)        2035
#
#  activation_242 (Activation)  (None, 28, 28, 55)       0
#
#  conv2d_183 (Conv2D)         (None, 28, 28, 55)        108955
#
#  activation_243 (Activation)  (None, 28, 28, 55)       0
#
#  max_pooling2d_91 (MaxPoolin  (None, 14, 14, 55)       0
#  g2D)
#
#  conv2d_184 (Conv2D)         (None, 14, 14, 61)        120841
#
#  activation_244 (Activation)  (None, 14, 14, 61)       0
#
#  conv2d_185 (Conv2D)         (None, 14, 14, 61)        134017
#
#  activation_245 (Activation)  (None, 14, 14, 61)       0
#
#  max_pooling2d_92 (MaxPoolin  (None, 7, 7, 61)         0
#  g2D)
#
#  flatten_30 (Flatten)        (None, 2989)              0
#
#  dense_60 (Dense)            (None, 128)               382720
#
#  activation_246 (Activation)  (None, 128)              0
#
#  dense_61 (Dense)            (None, 10)                1290
#
#  activation_247 (Activation)  (None, 10)               0
#
# =================================================================
# Total params: 749,858
# Trainable params: 749,858
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 469/469 [==============================] - 10s 20ms/step - loss: 0.1414 - accuracy: 0.9559
# Epoch 2/3
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0364 - accuracy: 0.9893
# Epoch 3/3
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0261 - accuracy: 0.9919

# %%
print(f"Best: {rand_result.best_score_} using {rand_result.best_params_}")
means = rand_result.cv_results_["mean_test_score"]
stds = rand_result.cv_results_["std_test_score"]
params = rand_result.cv_results_["params"]

for mean, std, param in zip(means, stds, params):
    print(f"Acc: {mean} (+/- {std * 2}) with: {param}")
# Out:
# Best: 0.9882000088691711 using {'filters_1': 52, 'filters_2': 55, 'filters_3': 61, 'kernel_size_1': 3, 'kernel_size_2': 6, 'kernel_size_3': 6}
# Acc: 0.9882000088691711 (+/- 0.002673322709131638) with: {'filters_1': 52, 'filters_2': 55, 'filters_3': 61, 'kernel_size_1': 3, 'kernel_size_2': 6, 'kernel_size_3': 6}
# Acc: 0.984933336575826 (+/- 0.004619037524970768) with: {'filters_1': 11, 'filters_2': 47, 'filters_3': 17, 'kernel_size_1': 6, 'kernel_size_2': 5, 'kernel_size_3': 7}
# Acc: 0.9870666662851969 (+/- 0.0014055205434198041) with: {'filters_1': 31, 'filters_2': 14, 'filters_3': 32, 'kernel_size_1': 3, 'kernel_size_2': 7, 'kernel_size_3': 5}
# Acc: 0.9874000151952108 (+/- 0.0013366405451055133) with: {'filters_1': 9, 'filters_2': 46, 'filters_3': 47, 'kernel_size_1': 3, 'kernel_size_2': 4, 'kernel_size_3': 4}
# Acc: 0.9821999867757162 (+/- 0.001979886341772047) with: {'filters_1': 21, 'filters_2': 16, 'filters_3': 17, 'kernel_size_1': 7, 'kernel_size_2': 6, 'kernel_size_3': 3}
# Acc: 0.9848499894142151 (+/- 0.0034727197481389436) with: {'filters_1': 59, 'filters_2': 13, 'filters_3': 23, 'kernel_size_1': 3, 'kernel_size_2': 5, 'kernel_size_3': 6}
# Acc: 0.9860333204269409 (+/- 0.003946594987658343) with: {'filters_1': 32, 'filters_2': 57, 'filters_3': 59, 'kernel_size_1': 6, 'kernel_size_2': 6, 'kernel_size_3': 3}
# Acc: 0.986300011475881 (+/- 0.0012832367619753484) with: {'filters_1': 9, 'filters_2': 17, 'filters_3': 40, 'kernel_size_1': 5, 'kernel_size_2': 7, 'kernel_size_3': 6}
# Acc: 0.9858166774113973 (+/- 0.0028158063250072305) with: {'filters_1': 19, 'filters_2': 58, 'filters_3': 63, 'kernel_size_1': 7, 'kernel_size_2': 5, 'kernel_size_3': 3}
# Acc: 0.9871500134468079 (+/- 0.0015297025249869905) with: {'filters_1': 8, 'filters_2': 44, 'filters_3': 61, 'kernel_size_1': 3, 'kernel_size_2': 7, 'kernel_size_3': 4}
