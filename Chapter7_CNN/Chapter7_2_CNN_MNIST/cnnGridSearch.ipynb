# %% [markdown]
# In diesem Skript wird nicht auf ein sequentielles Model (Sequential) gesetzt, sondern auf ein Model

# %%
import numpy as np
import tensorflow as tf

from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import MaxPool2D

from sklearn.model_selection import cross_val_score
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV # GridSearch + CrossValidation

from mnistData import MNIST
# Out:
# Train size: 60000
# Test size: 10000
# Train shape: (60000, 28, 28, 1)
# Test shape: (10000, 28, 28, 1)
# Min of x_train: 0.0
# Max of x_train: 1.0

# %%
np.random.seed(0)
tf.random.set_seed(0)

# %%
def build_model(
    filters_1: int,
    kernel_size_1: int,
    filters_2: int,
    kernel_size_2: int,
    filters_3: int,
    kernel_size_3: int
) -> Model:
    input_img = Input(shape=(28,28,1))

    x = Conv2D(filters=filters_1, kernel_size=kernel_size_1, padding='same')(input_img)
    x = Activation("relu")(x)
    x = Conv2D(filters=filters_1, kernel_size=kernel_size_1, padding='same')(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)

    x = Conv2D(filters=filters_2, kernel_size=kernel_size_2, padding='same')(input_img)
    x = Activation('relu')(x)
    x = Conv2D(filters=filters_2, kernel_size=kernel_size_2, padding='same')(x)
    x = Activation('relu')(x)
    x = MaxPool2D()(x)

    x = Conv2D(filters=filters_3, kernel_size=kernel_size_3, padding='same')(x)
    x = Activation('relu')(x)
    x = Conv2D(filters=filters_3, kernel_size=kernel_size_3, padding='same')(x)
    x = Activation('relu')(x)
    x = MaxPool2D()(x)

    x = Flatten()(x)
    x = Dense(units=128)(x)
    x = Activation("relu")(x)
    x = Dense(units=10)(x)
    y_pred = Activation("softmax")(x)

    model = Model(
        inputs = [input_img],
        outputs = [y_pred]
    )

    model.compile( 
        loss='categorical_crossentropy',
        optimizer='Adam',
        metrics=['accuracy']
    )
    
    model.summary()

    return model

# %%
data = MNIST(with_normalization=True)
x_train, y_train = data.get_train_set()

param_grid = {
    'filters_1': [16, 32],
    'kernel_size_1': [3, 5],
    'filters_2': [32, 64],
    'kernel_size_2': [3, 5],
    'filters_3': [64, 128],
    'kernel_size_3': [5]
}

keras_clf = KerasClassifier(
    build_fn=build_model, # Funktionsobjekt übergeben, Fit-Methode ist hier intern gelöst und Parameter müssen angegeben werden
    epochs=3,
    batch_size=128,
    verbose=1
)

grid_cv = GridSearchCV(
    estimator=keras_clf,
    param_grid=param_grid,
    n_jobs=1,
    verbose=0,
    cv=3
)

grid_result = grid_cv.fit(x_train, y_train)
# Out:
# C:\Users\gutsc\AppData\Local\Temp/ipykernel_3196/1731250149.py:13: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead.
#   keras_clf = KerasClassifier(
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 32)        320
#
#  activation_2 (Activation)   (None, 28, 28, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 32)        9248
#
#  activation_3 (Activation)   (None, 28, 28, 32)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 64)        51264
#
#  activation_4 (Activation)   (None, 14, 14, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 64)        102464
#
#  activation_5 (Activation)   (None, 14, 14, 64)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 128)               401536
#
#  activation_6 (Activation)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
#  activation_7 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 566,122
# Trainable params: 566,122
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 12s 10ms/step - loss: 0.1973 - accuracy: 0.9376
# Epoch 2/3
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0495 - accuracy: 0.9844
# Epoch 3/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0328 - accuracy: 0.9893
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0452 - accuracy: 0.9866
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 32)        320
#
#  activation_10 (Activation)  (None, 28, 28, 32)        0
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 32)        9248
#
#  activation_11 (Activation)  (None, 28, 28, 32)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 64)        51264
#
#  activation_12 (Activation)  (None, 14, 14, 64)        0
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 64)        102464
#
#  activation_13 (Activation)  (None, 14, 14, 64)        0
#
#  max_pooling2d_5 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 3136)              0
#
#  dense_2 (Dense)             (None, 128)               401536
#
#  activation_14 (Activation)  (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
#  activation_15 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 566,122
# Trainable params: 566,122
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.1971 - accuracy: 0.9378
# Epoch 2/3
# 313/313 [==============================] - 2s 8ms/step - loss: 0.0464 - accuracy: 0.9859
# Epoch 3/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0296 - accuracy: 0.9903
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0439 - accuracy: 0.9876
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_14 (Conv2D)          (None, 28, 28, 32)        320
#
#  activation_18 (Activation)  (None, 28, 28, 32)        0
#
#  conv2d_15 (Conv2D)          (None, 28, 28, 32)        9248
#
#  activation_19 (Activation)  (None, 28, 28, 32)        0
#
#  max_pooling2d_7 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_16 (Conv2D)          (None, 14, 14, 64)        51264
#
#  activation_20 (Activation)  (None, 14, 14, 64)        0
#
#  conv2d_17 (Conv2D)          (None, 14, 14, 64)        102464
#
#  activation_21 (Activation)  (None, 14, 14, 64)        0
#
#  max_pooling2d_8 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 3136)              0
#
#  dense_4 (Dense)             (None, 128)               401536
#
#  activation_22 (Activation)  (None, 128)               0
#
#  dense_5 (Dense)             (None, 10)                1290
#
#  activation_23 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 566,122
# Trainable params: 566,122
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.1868 - accuracy: 0.9417
# Epoch 2/3
# 313/313 [==============================] - 2s 8ms/step - loss: 0.0452 - accuracy: 0.9862
# Epoch 3/3
# 313/313 [==============================] - 2s 8ms/step - loss: 0.0278 - accuracy: 0.9911
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0395 - accuracy: 0.9877
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_20 (Conv2D)          (None, 28, 28, 32)        832
#
#  activation_26 (Activation)  (None, 28, 28, 32)        0
#
#  conv2d_21 (Conv2D)          (None, 28, 28, 32)        25632
#
#  activation_27 (Activation)  (None, 28, 28, 32)        0
#
#  max_pooling2d_10 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 64)        51264
#
#  activation_28 (Activation)  (None, 14, 14, 64)        0
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 64)        102464
#
#  activation_29 (Activation)  (None, 14, 14, 64)        0
#
#  max_pooling2d_11 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 3136)              0
#
#  dense_6 (Dense)             (None, 128)               401536
#
#  activation_30 (Activation)  (None, 128)               0
#
#  dense_7 (Dense)             (None, 10)                1290
#
#  activation_31 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 583,018
# Trainable params: 583,018
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.1946 - accuracy: 0.9369
# Epoch 2/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0485 - accuracy: 0.9850
# Epoch 3/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0322 - accuracy: 0.9897
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0429 - accuracy: 0.9883
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_26 (Conv2D)          (None, 28, 28, 32)        832
#
#  activation_34 (Activation)  (None, 28, 28, 32)        0
#
#  conv2d_27 (Conv2D)          (None, 28, 28, 32)        25632
#
#  activation_35 (Activation)  (None, 28, 28, 32)        0
#
#  max_pooling2d_13 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 14, 14, 64)        51264
#
#  activation_36 (Activation)  (None, 14, 14, 64)        0
#
#  conv2d_29 (Conv2D)          (None, 14, 14, 64)        102464
#
#  activation_37 (Activation)  (None, 14, 14, 64)        0
#
#  max_pooling2d_14 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 3136)              0
#
#  dense_8 (Dense)             (None, 128)               401536
#
#  activation_38 (Activation)  (None, 128)               0
#
#  dense_9 (Dense)             (None, 10)                1290
#
#  activation_39 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 583,018
# Trainable params: 583,018
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.2009 - accuracy: 0.9351
# Epoch 2/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0484 - accuracy: 0.9853
# Epoch 3/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0327 - accuracy: 0.9897
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0428 - accuracy: 0.9877
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_32 (Conv2D)          (None, 28, 28, 32)        832
#
#  activation_42 (Activation)  (None, 28, 28, 32)        0
#
#  conv2d_33 (Conv2D)          (None, 28, 28, 32)        25632
#
#  activation_43 (Activation)  (None, 28, 28, 32)        0
#
#  max_pooling2d_16 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 14, 14, 64)        51264
#
#  activation_44 (Activation)  (None, 14, 14, 64)        0
#
#  conv2d_35 (Conv2D)          (None, 14, 14, 64)        102464
#
#  activation_45 (Activation)  (None, 14, 14, 64)        0
#
#  max_pooling2d_17 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 3136)              0
#
#  dense_10 (Dense)            (None, 128)               401536
#
#  activation_46 (Activation)  (None, 128)               0
#
#  dense_11 (Dense)            (None, 10)                1290
#
#  activation_47 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 583,018
# Trainable params: 583,018
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1972 - accuracy: 0.9378
# Epoch 2/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0490 - accuracy: 0.9848
# Epoch 3/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0325 - accuracy: 0.9897
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0380 - accuracy: 0.9889
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_38 (Conv2D)          (None, 28, 28, 32)        320
#
#  activation_50 (Activation)  (None, 28, 28, 32)        0
#
#  conv2d_39 (Conv2D)          (None, 28, 28, 32)        9248
#
#  activation_51 (Activation)  (None, 28, 28, 32)        0
#
#  max_pooling2d_19 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_40 (Conv2D)          (None, 14, 14, 64)        51264
#
#  activation_52 (Activation)  (None, 14, 14, 64)        0
#
#  conv2d_41 (Conv2D)          (None, 14, 14, 64)        102464
#
#  activation_53 (Activation)  (None, 14, 14, 64)        0
#
#  max_pooling2d_20 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 3136)              0
#
#  dense_12 (Dense)            (None, 128)               401536
#
#  activation_54 (Activation)  (None, 128)               0
#
#  dense_13 (Dense)            (None, 10)                1290
#
#  activation_55 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 566,122
# Trainable params: 566,122
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.2103 - accuracy: 0.9330
# Epoch 2/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0500 - accuracy: 0.9842
# Epoch 3/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0331 - accuracy: 0.9897
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0415 - accuracy: 0.9873
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_44 (Conv2D)          (None, 28, 28, 32)        320
#
#  activation_58 (Activation)  (None, 28, 28, 32)        0
#
#  conv2d_45 (Conv2D)          (None, 28, 28, 32)        9248
#
#  activation_59 (Activation)  (None, 28, 28, 32)        0
#
#  max_pooling2d_22 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_46 (Conv2D)          (None, 14, 14, 64)        51264
#
#  activation_60 (Activation)  (None, 14, 14, 64)        0
#
#  conv2d_47 (Conv2D)          (None, 14, 14, 64)        102464
#
#  activation_61 (Activation)  (None, 14, 14, 64)        0
#
#  max_pooling2d_23 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 3136)              0
#
#  dense_14 (Dense)            (None, 128)               401536
#
#  activation_62 (Activation)  (None, 128)               0
#
#  dense_15 (Dense)            (None, 10)                1290
#
#  activation_63 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 566,122
# Trainable params: 566,122
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.2077 - accuracy: 0.9337
# Epoch 2/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0471 - accuracy: 0.9859
# Epoch 3/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0315 - accuracy: 0.9900
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0520 - accuracy: 0.9851
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_50 (Conv2D)          (None, 28, 28, 32)        320
#
#  activation_66 (Activation)  (None, 28, 28, 32)        0
#
#  conv2d_51 (Conv2D)          (None, 28, 28, 32)        9248
#
#  activation_67 (Activation)  (None, 28, 28, 32)        0
#
#  max_pooling2d_25 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_52 (Conv2D)          (None, 14, 14, 64)        51264
#
#  activation_68 (Activation)  (None, 14, 14, 64)        0
#
#  conv2d_53 (Conv2D)          (None, 14, 14, 64)        102464
#
#  activation_69 (Activation)  (None, 14, 14, 64)        0
#
#  max_pooling2d_26 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 3136)              0
#
#  dense_16 (Dense)            (None, 128)               401536
#
#  activation_70 (Activation)  (None, 128)               0
#
#  dense_17 (Dense)            (None, 10)                1290
#
#  activation_71 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 566,122
# Trainable params: 566,122
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.1935 - accuracy: 0.9400
# Epoch 2/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0460 - accuracy: 0.9851
# Epoch 3/3
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0286 - accuracy: 0.9907
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0390 - accuracy: 0.9889
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_56 (Conv2D)          (None, 28, 28, 32)        832
#
#  activation_74 (Activation)  (None, 28, 28, 32)        0
#
#  conv2d_57 (Conv2D)          (None, 28, 28, 32)        25632
#
#  activation_75 (Activation)  (None, 28, 28, 32)        0
#
#  max_pooling2d_28 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_58 (Conv2D)          (None, 14, 14, 64)        51264
#
#  activation_76 (Activation)  (None, 14, 14, 64)        0
#
#  conv2d_59 (Conv2D)          (None, 14, 14, 64)        102464
#
#  activation_77 (Activation)  (None, 14, 14, 64)        0
#
#  max_pooling2d_29 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  flatten_9 (Flatten)         (None, 3136)              0
#
#  dense_18 (Dense)            (None, 128)               401536
#
#  activation_78 (Activation)  (None, 128)               0
#
#  dense_19 (Dense)            (None, 10)                1290
#
#  activation_79 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 583,018
# Trainable params: 583,018
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1966 - accuracy: 0.9377
# Epoch 2/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0494 - accuracy: 0.9847
# Epoch 3/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0327 - accuracy: 0.9893
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0459 - accuracy: 0.9861
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_62 (Conv2D)          (None, 28, 28, 32)        832
#
#  activation_82 (Activation)  (None, 28, 28, 32)        0
#
#  conv2d_63 (Conv2D)          (None, 28, 28, 32)        25632
#
#  activation_83 (Activation)  (None, 28, 28, 32)        0
#
#  max_pooling2d_31 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_64 (Conv2D)          (None, 14, 14, 64)        51264
#
#  activation_84 (Activation)  (None, 14, 14, 64)        0
#
#  conv2d_65 (Conv2D)          (None, 14, 14, 64)        102464
#
#  activation_85 (Activation)  (None, 14, 14, 64)        0
#
#  max_pooling2d_32 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 3136)              0
#
#  dense_20 (Dense)            (None, 128)               401536
#
#  activation_86 (Activation)  (None, 128)               0
#
#  dense_21 (Dense)            (None, 10)                1290
#
#  activation_87 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 583,018
# Trainable params: 583,018
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.2027 - accuracy: 0.9352
# Epoch 2/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0460 - accuracy: 0.9860
# Epoch 3/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0327 - accuracy: 0.9898
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0415 - accuracy: 0.9877
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_68 (Conv2D)          (None, 28, 28, 32)        832
#
#  activation_90 (Activation)  (None, 28, 28, 32)        0
#
#  conv2d_69 (Conv2D)          (None, 28, 28, 32)        25632
#
#  activation_91 (Activation)  (None, 28, 28, 32)        0
#
#  max_pooling2d_34 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_70 (Conv2D)          (None, 14, 14, 64)        51264
#
#  activation_92 (Activation)  (None, 14, 14, 64)        0
#
#  conv2d_71 (Conv2D)          (None, 14, 14, 64)        102464
#
#  activation_93 (Activation)  (None, 14, 14, 64)        0
#
#  max_pooling2d_35 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  flatten_11 (Flatten)        (None, 3136)              0
#
#  dense_22 (Dense)            (None, 128)               401536
#
#  activation_94 (Activation)  (None, 128)               0
#
#  dense_23 (Dense)            (None, 10)                1290
#
#  activation_95 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 583,018
# Trainable params: 583,018
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.2041 - accuracy: 0.9365
# Epoch 2/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0494 - accuracy: 0.9845
# Epoch 3/3
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0305 - accuracy: 0.9904
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0400 - accuracy: 0.9880
# Model: "model_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_74 (Conv2D)          (None, 28, 28, 32)        320
#
#  activation_98 (Activation)  (None, 28, 28, 32)        0
#
#  conv2d_75 (Conv2D)          (None, 28, 28, 32)        9248
#
#  activation_99 (Activation)  (None, 28, 28, 32)        0
#
#  max_pooling2d_37 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_76 (Conv2D)          (None, 14, 14, 128)       102528
#
#  activation_100 (Activation)  (None, 14, 14, 128)      0
#
#  conv2d_77 (Conv2D)          (None, 14, 14, 128)       409728
#
#  activation_101 (Activation)  (None, 14, 14, 128)      0
#
#  max_pooling2d_38 (MaxPoolin  (None, 7, 7, 128)        0
#  g2D)
#
#  flatten_12 (Flatten)        (None, 6272)              0
#
#  dense_24 (Dense)            (None, 128)               802944
#
#  activation_102 (Activation)  (None, 128)              0
#
#  dense_25 (Dense)            (None, 10)                1290
#
#  activation_103 (Activation)  (None, 10)               0
#
# =================================================================
# Total params: 1,326,058
# Trainable params: 1,326,058
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 4s 12ms/step - loss: 0.1891 - accuracy: 0.9393
# Epoch 2/3
# 313/313 [==============================] - 4s 11ms/step - loss: 0.0441 - accuracy: 0.9860
# Epoch 3/3
# 313/313 [==============================] - 4s 12ms/step - loss: 0.0285 - accuracy: 0.9909
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0402 - accuracy: 0.9883
# Model: "model_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_80 (Conv2D)          (None, 28, 28, 32)        320
#
#  activation_106 (Activation)  (None, 28, 28, 32)       0
#
#  conv2d_81 (Conv2D)          (None, 28, 28, 32)        9248
#
#  activation_107 (Activation)  (None, 28, 28, 32)       0
#
#  max_pooling2d_40 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_82 (Conv2D)          (None, 14, 14, 128)       102528
#
#  activation_108 (Activation)  (None, 14, 14, 128)      0
#
#  conv2d_83 (Conv2D)          (None, 14, 14, 128)       409728
#
#  activation_109 (Activation)  (None, 14, 14, 128)      0
#
#  max_pooling2d_41 (MaxPoolin  (None, 7, 7, 128)        0
#  g2D)
#
#  flatten_13 (Flatten)        (None, 6272)              0
#
#  dense_26 (Dense)            (None, 128)               802944
#
#  activation_110 (Activation)  (None, 128)              0
#
#  dense_27 (Dense)            (None, 10)                1290
#
#  activation_111 (Activation)  (None, 10)               0
#
# =================================================================
# Total params: 1,326,058
# Trainable params: 1,326,058
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 4s 11ms/step - loss: 0.1763 - accuracy: 0.9420
# Epoch 2/3
# 313/313 [==============================] - 4s 13ms/step - loss: 0.0412 - accuracy: 0.9876
# Epoch 3/3
# 313/313 [==============================] - 4s 12ms/step - loss: 0.0280 - accuracy: 0.9915
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0488 - accuracy: 0.9858
# Model: "model_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_15 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_86 (Conv2D)          (None, 28, 28, 32)        320
#
#  activation_114 (Activation)  (None, 28, 28, 32)       0
#
#  conv2d_87 (Conv2D)          (None, 28, 28, 32)        9248
#
#  activation_115 (Activation)  (None, 28, 28, 32)       0
#
#  max_pooling2d_43 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_88 (Conv2D)          (None, 14, 14, 128)       102528
#
#  activation_116 (Activation)  (None, 14, 14, 128)      0
#
#  conv2d_89 (Conv2D)          (None, 14, 14, 128)       409728
#
#  activation_117 (Activation)  (None, 14, 14, 128)      0
#
#  max_pooling2d_44 (MaxPoolin  (None, 7, 7, 128)        0
#  g2D)
#
#  flatten_14 (Flatten)        (None, 6272)              0
#
#  dense_28 (Dense)            (None, 128)               802944
#
#  activation_118 (Activation)  (None, 128)              0
#
#  dense_29 (Dense)            (None, 10)                1290
#
#  activation_119 (Activation)  (None, 10)               0
#
# =================================================================
# Total params: 1,326,058
# Trainable params: 1,326,058
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 4s 12ms/step - loss: 0.1750 - accuracy: 0.9445
# Epoch 2/3
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0440 - accuracy: 0.9863
# Epoch 3/3
# 313/313 [==============================] - 4s 12ms/step - loss: 0.0264 - accuracy: 0.9918
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0390 - accuracy: 0.9875
# Model: "model_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_16 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_92 (Conv2D)          (None, 28, 28, 32)        832
#
#  activation_122 (Activation)  (None, 28, 28, 32)       0
#
#  conv2d_93 (Conv2D)          (None, 28, 28, 32)        25632
#
#  activation_123 (Activation)  (None, 28, 28, 32)       0
#
#  max_pooling2d_46 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_94 (Conv2D)          (None, 14, 14, 128)       102528
#
#  activation_124 (Activation)  (None, 14, 14, 128)      0
#
#  conv2d_95 (Conv2D)          (None, 14, 14, 128)       409728
#
#  activation_125 (Activation)  (None, 14, 14, 128)      0
#
#  max_pooling2d_47 (MaxPoolin  (None, 7, 7, 128)        0
#  g2D)
#
#  flatten_15 (Flatten)        (None, 6272)              0
#
#  dense_30 (Dense)            (None, 128)               802944
# ...
#
#  activation_735 (Activation)  (None, 10)               0
#
# =================================================================
# Total params: 1,456,458
# Trainable params: 1,456,458
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 5s 14ms/step - loss: 0.1777 - accuracy: 0.9416
# Epoch 2/3
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0394 - accuracy: 0.9884
# Epoch 3/3
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0281 - accuracy: 0.9913
# 157/157 [==============================] - 1s 6ms/step - loss: 0.0421 - accuracy: 0.9884
# Model: "model_92"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_93 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_554 (Conv2D)         (None, 28, 28, 64)        640
#
#  activation_738 (Activation)  (None, 28, 28, 64)       0
#
#  conv2d_555 (Conv2D)         (None, 28, 28, 64)        36928
#
#  activation_739 (Activation)  (None, 28, 28, 64)       0
#
#  max_pooling2d_277 (MaxPooli  (None, 14, 14, 64)       0
#  ng2D)
#
#  conv2d_556 (Conv2D)         (None, 14, 14, 128)       204928
#
#  activation_740 (Activation)  (None, 14, 14, 128)      0
#
#  conv2d_557 (Conv2D)         (None, 14, 14, 128)       409728
#
#  activation_741 (Activation)  (None, 14, 14, 128)      0
#
#  max_pooling2d_278 (MaxPooli  (None, 7, 7, 128)        0
#  ng2D)
#
#  flatten_92 (Flatten)        (None, 6272)              0
#
#  dense_184 (Dense)           (None, 128)               802944
#
#  activation_742 (Activation)  (None, 128)              0
#
#  dense_185 (Dense)           (None, 10)                1290
#
#  activation_743 (Activation)  (None, 10)               0
#
# =================================================================
# Total params: 1,456,458
# Trainable params: 1,456,458
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 5s 14ms/step - loss: 0.1730 - accuracy: 0.9450
# Epoch 2/3
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0402 - accuracy: 0.9871
# Epoch 3/3
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0276 - accuracy: 0.9915
# 157/157 [==============================] - 1s 6ms/step - loss: 0.0371 - accuracy: 0.9887
# Model: "model_93"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_94 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_560 (Conv2D)         (None, 28, 28, 64)        1664
#
#  activation_746 (Activation)  (None, 28, 28, 64)       0
#
#  conv2d_561 (Conv2D)         (None, 28, 28, 64)        102464
#
#  activation_747 (Activation)  (None, 28, 28, 64)       0
#
#  max_pooling2d_280 (MaxPooli  (None, 14, 14, 64)       0
#  ng2D)
#
#  conv2d_562 (Conv2D)         (None, 14, 14, 128)       204928
#
#  activation_748 (Activation)  (None, 14, 14, 128)      0
#
#  conv2d_563 (Conv2D)         (None, 14, 14, 128)       409728
#
#  activation_749 (Activation)  (None, 14, 14, 128)      0
#
#  max_pooling2d_281 (MaxPooli  (None, 7, 7, 128)        0
#  ng2D)
#
#  flatten_93 (Flatten)        (None, 6272)              0
#
#  dense_186 (Dense)           (None, 128)               802944
#
#  activation_750 (Activation)  (None, 128)              0
#
#  dense_187 (Dense)           (None, 10)                1290
#
#  activation_751 (Activation)  (None, 10)               0
#
# =================================================================
# Total params: 1,523,018
# Trainable params: 1,523,018
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 5s 14ms/step - loss: 0.1826 - accuracy: 0.9422
# Epoch 2/3
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0439 - accuracy: 0.9862
# Epoch 3/3
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0289 - accuracy: 0.9911
# 157/157 [==============================] - 1s 6ms/step - loss: 0.0365 - accuracy: 0.9892
# Model: "model_94"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_95 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_566 (Conv2D)         (None, 28, 28, 64)        1664
#
#  activation_754 (Activation)  (None, 28, 28, 64)       0
#
#  conv2d_567 (Conv2D)         (None, 28, 28, 64)        102464
#
#  activation_755 (Activation)  (None, 28, 28, 64)       0
#
#  max_pooling2d_283 (MaxPooli  (None, 14, 14, 64)       0
#  ng2D)
#
#  conv2d_568 (Conv2D)         (None, 14, 14, 128)       204928
#
#  activation_756 (Activation)  (None, 14, 14, 128)      0
#
#  conv2d_569 (Conv2D)         (None, 14, 14, 128)       409728
#
#  activation_757 (Activation)  (None, 14, 14, 128)      0
#
#  max_pooling2d_284 (MaxPooli  (None, 7, 7, 128)        0
#  ng2D)
#
#  flatten_94 (Flatten)        (None, 6272)              0
#
#  dense_188 (Dense)           (None, 128)               802944
#
#  activation_758 (Activation)  (None, 128)              0
#
#  dense_189 (Dense)           (None, 10)                1290
#
#  activation_759 (Activation)  (None, 10)               0
#
# =================================================================
# Total params: 1,523,018
# Trainable params: 1,523,018
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 5s 14ms/step - loss: 0.1659 - accuracy: 0.9466
# Epoch 2/3
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0421 - accuracy: 0.9870
# Epoch 3/3
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0288 - accuracy: 0.9912
# 157/157 [==============================] - 1s 6ms/step - loss: 0.0484 - accuracy: 0.9869
# Model: "model_95"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_96 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_572 (Conv2D)         (None, 28, 28, 64)        1664
#
#  activation_762 (Activation)  (None, 28, 28, 64)       0
#
#  conv2d_573 (Conv2D)         (None, 28, 28, 64)        102464
#
#  activation_763 (Activation)  (None, 28, 28, 64)       0
#
#  max_pooling2d_286 (MaxPooli  (None, 14, 14, 64)       0
#  ng2D)
#
#  conv2d_574 (Conv2D)         (None, 14, 14, 128)       204928
#
#  activation_764 (Activation)  (None, 14, 14, 128)      0
#
#  conv2d_575 (Conv2D)         (None, 14, 14, 128)       409728
#
#  activation_765 (Activation)  (None, 14, 14, 128)      0
#
#  max_pooling2d_287 (MaxPooli  (None, 7, 7, 128)        0
#  ng2D)
#
#  flatten_95 (Flatten)        (None, 6272)              0
#
#  dense_190 (Dense)           (None, 128)               802944
#
#  activation_766 (Activation)  (None, 128)              0
#
#  dense_191 (Dense)           (None, 10)                1290
#
#  activation_767 (Activation)  (None, 10)               0
#
# =================================================================
# Total params: 1,523,018
# Trainable params: 1,523,018
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 313/313 [==============================] - 5s 14ms/step - loss: 0.1880 - accuracy: 0.9381
# Epoch 2/3
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0432 - accuracy: 0.9862
# Epoch 3/3
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0282 - accuracy: 0.9913
# 157/157 [==============================] - 1s 6ms/step - loss: 0.0392 - accuracy: 0.9877
# Model: "model_96"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_97 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_578 (Conv2D)         (None, 28, 28, 32)        832
#
#  activation_770 (Activation)  (None, 28, 28, 32)       0
#
#  conv2d_579 (Conv2D)         (None, 28, 28, 32)        25632
#
#  activation_771 (Activation)  (None, 28, 28, 32)       0
#
#  max_pooling2d_289 (MaxPooli  (None, 14, 14, 32)       0
#  ng2D)
#
#  conv2d_580 (Conv2D)         (None, 14, 14, 128)       102528
#
#  activation_772 (Activation)  (None, 14, 14, 128)      0
#
#  conv2d_581 (Conv2D)         (None, 14, 14, 128)       409728
#
#  activation_773 (Activation)  (None, 14, 14, 128)      0
#
#  max_pooling2d_290 (MaxPooli  (None, 7, 7, 128)        0
#  ng2D)
#
#  flatten_96 (Flatten)        (None, 6272)              0
#
#  dense_192 (Dense)           (None, 128)               802944
#
#  activation_774 (Activation)  (None, 128)              0
#
#  dense_193 (Dense)           (None, 10)                1290
#
#  activation_775 (Activation)  (None, 10)               0
#
# =================================================================
# Total params: 1,342,954
# Trainable params: 1,342,954
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1432 - accuracy: 0.9557
# Epoch 2/3
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0368 - accuracy: 0.9891
# Epoch 3/3
# 469/469 [==============================] - 5s 12ms/step - loss: 0.0253 - accuracy: 0.9921

# %%
print(f"Best: {grid_result.best_score_} using {grid_result.best_params_}")
means = grid_result.cv_results_["mean_test_score"]
stds = grid_result.cv_results_["std_test_score"]
params = grid_result.cv_results_["params"]

for mean, std, param in zip(means, stds, params):
    print(f"Acc: {mean} (+/- {std * 2}) with: {param}")
# Out:
# Best: 0.9896833300590515 using {'filters_1': 32, 'filters_2': 32, 'filters_3': 128, 'kernel_size_1': 5, 'kernel_size_2': 5, 'kernel_size_3': 5}
# Acc: 0.9873499870300293 (+/- 0.0009933077742932473) with: {'filters_1': 16, 'filters_2': 32, 'filters_3': 64, 'kernel_size_1': 3, 'kernel_size_2': 3, 'kernel_size_3': 5}
# Acc: 0.9882833361625671 (+/- 0.0009809448570342369) with: {'filters_1': 16, 'filters_2': 32, 'filters_3': 64, 'kernel_size_1': 3, 'kernel_size_2': 5, 'kernel_size_3': 5}
# Acc: 0.9871000051498413 (+/- 0.0031633150943912547) with: {'filters_1': 16, 'filters_2': 32, 'filters_3': 64, 'kernel_size_1': 5, 'kernel_size_2': 3, 'kernel_size_3': 5}
# Acc: 0.9872666796048483 (+/- 0.0016579728598135972) with: {'filters_1': 16, 'filters_2': 32, 'filters_3': 64, 'kernel_size_1': 5, 'kernel_size_2': 5, 'kernel_size_3': 5}
# Acc: 0.9871833523114523 (+/- 0.0021296870004828884) with: {'filters_1': 16, 'filters_2': 32, 'filters_3': 128, 'kernel_size_1': 3, 'kernel_size_2': 3, 'kernel_size_3': 5}
# Acc: 0.9887666702270508 (+/- 0.0009977921931997903) with: {'filters_1': 16, 'filters_2': 32, 'filters_3': 128, 'kernel_size_1': 3, 'kernel_size_2': 5, 'kernel_size_3': 5}
# Acc: 0.9874499837557474 (+/- 0.0012355859564395731) with: {'filters_1': 16, 'filters_2': 32, 'filters_3': 128, 'kernel_size_1': 5, 'kernel_size_2': 3, 'kernel_size_3': 5}
# Acc: 0.9875500003496805 (+/- 0.002021573477864738) with: {'filters_1': 16, 'filters_2': 32, 'filters_3': 128, 'kernel_size_1': 5, 'kernel_size_2': 5, 'kernel_size_3': 5}
# Acc: 0.988099992275238 (+/- 0.0010033279486764853) with: {'filters_1': 16, 'filters_2': 64, 'filters_3': 64, 'kernel_size_1': 3, 'kernel_size_2': 3, 'kernel_size_3': 5}
# Acc: 0.9872333407402039 (+/- 0.0011085382190009695) with: {'filters_1': 16, 'filters_2': 64, 'filters_3': 64, 'kernel_size_1': 3, 'kernel_size_2': 5, 'kernel_size_3': 5}
# Acc: 0.9876333276430765 (+/- 0.0033638317133555967) with: {'filters_1': 16, 'filters_2': 64, 'filters_3': 64, 'kernel_size_1': 5, 'kernel_size_2': 3, 'kernel_size_3': 5}
# Acc: 0.9874500036239624 (+/- 0.001720459532629063) with: {'filters_1': 16, 'filters_2': 64, 'filters_3': 64, 'kernel_size_1': 5, 'kernel_size_2': 5, 'kernel_size_3': 5}
# Acc: 0.9884166518847147 (+/- 0.0006599795079713539) with: {'filters_1': 16, 'filters_2': 64, 'filters_3': 128, 'kernel_size_1': 3, 'kernel_size_2': 3, 'kernel_size_3': 5}
# Acc: 0.9879999955495199 (+/- 0.0008485565500193331) with: {'filters_1': 16, 'filters_2': 64, 'filters_3': 128, 'kernel_size_1': 3, 'kernel_size_2': 5, 'kernel_size_3': 5}
# Acc: 0.9886333147684733 (+/- 0.0007318258339462339) with: {'filters_1': 16, 'filters_2': 64, 'filters_3': 128, 'kernel_size_1': 5, 'kernel_size_2': 3, 'kernel_size_3': 5}
# Acc: 0.9867999951044718 (+/- 0.0015769340671339062) with: {'filters_1': 16, 'filters_2': 64, 'filters_3': 128, 'kernel_size_1': 5, 'kernel_size_2': 5, 'kernel_size_3': 5}
# Acc: 0.9872999986012777 (+/- 0.0003741747279039524) with: {'filters_1': 32, 'filters_2': 32, 'filters_3': 64, 'kernel_size_1': 3, 'kernel_size_2': 3, 'kernel_size_3': 5}
# Acc: 0.9877666632334391 (+/- 0.0004988748569238301) with: {'filters_1': 32, 'filters_2': 32, 'filters_3': 64, 'kernel_size_1': 3, 'kernel_size_2': 5, 'kernel_size_3': 5}
# Acc: 0.9872333407402039 (+/- 0.0031137860019644) with: {'filters_1': 32, 'filters_2': 32, 'filters_3': 64, 'kernel_size_1': 5, 'kernel_size_2': 3, 'kernel_size_3': 5}
# Acc: 0.986633320649465 (+/- 0.0027145751954762787) with: {'filters_1': 32, 'filters_2': 32, 'filters_3': 64, 'kernel_size_1': 5, 'kernel_size_2': 5, 'kernel_size_3': 5}
# Acc: 0.9873166481653849 (+/- 0.002094964252582283) with: {'filters_1': 32, 'filters_2': 32, 'filters_3': 128, 'kernel_size_1': 3, 'kernel_size_2': 3, 'kernel_size_3': 5}
# Acc: 0.9884666601816813 (+/- 0.0005557770134126751) with: {'filters_1': 32, 'filters_2': 32, 'filters_3': 128, 'kernel_size_1': 3, 'kernel_size_2': 5, 'kernel_size_3': 5}
# Acc: 0.9881500204404196 (+/- 0.0011775610534903026) with: {'filters_1': 32, 'filters_2': 32, 'filters_3': 128, 'kernel_size_1': 5, 'kernel_size_2': 3, 'kernel_size_3': 5}
# Acc: 0.9896833300590515 (+/- 0.0007039252391863594) with: {'filters_1': 32, 'filters_2': 32, 'filters_3': 128, 'kernel_size_1': 5, 'kernel_size_2': 5, 'kernel_size_3': 5}
# Acc: 0.9878666599591573 (+/- 0.00018853690233873265) with: {'filters_1': 32, 'filters_2': 64, 'filters_3': 64, 'kernel_size_1': 3, 'kernel_size_2': 3, 'kernel_size_3': 5}
# Acc: 0.9878666599591573 (+/- 0.003104098279322089) with: {'filters_1': 32, 'filters_2': 64, 'filters_3': 64, 'kernel_size_1': 3, 'kernel_size_2': 5, 'kernel_size_3': 5}
# Acc: 0.9874666531880697 (+/- 0.001649908629706465) with: {'filters_1': 32, 'filters_2': 64, 'filters_3': 64, 'kernel_size_1': 5, 'kernel_size_2': 3, 'kernel_size_3': 5}
# Acc: 0.9873999953269958 (+/- 0.0021213351792503184) with: {'filters_1': 32, 'filters_2': 64, 'filters_3': 64, 'kernel_size_1': 5, 'kernel_size_2': 5, 'kernel_size_3': 5}
# Acc: 0.9876499970753988 (+/- 0.002299252386060677) with: {'filters_1': 32, 'filters_2': 64, 'filters_3': 128, 'kernel_size_1': 3, 'kernel_size_2': 3, 'kernel_size_3': 5}
# Acc: 0.9888999859491984 (+/- 0.00029438688933019596) with: {'filters_1': 32, 'filters_2': 64, 'filters_3': 128, 'kernel_size_1': 3, 'kernel_size_2': 5, 'kernel_size_3': 5}
# Acc: 0.9886999924977621 (+/- 0.0003741747279039524) with: {'filters_1': 32, 'filters_2': 64, 'filters_3': 128, 'kernel_size_1': 5, 'kernel_size_2': 3, 'kernel_size_3': 5}
# Acc: 0.9879333178202311 (+/- 0.0019067323636153231) with: {'filters_1': 32, 'filters_2': 64, 'filters_3': 128, 'kernel_size_1': 5, 'kernel_size_2': 5, 'kernel_size_3': 5}
