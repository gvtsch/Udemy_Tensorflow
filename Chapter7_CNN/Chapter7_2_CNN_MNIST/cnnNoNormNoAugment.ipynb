# %% [markdown]
# In diesem Skript wird nicht auf ein sequentielles Model (Sequential) gesetzt, sondern auf ein Model

# %%
import os # Arbeiten mit Pfaden
import numpy as np
from typing import Tuple

from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import MaxPooling2D

import matplotlib.pyplot as plt

from mnistData import MNIST

# %%
LOGS_DIR = os.path.abspath('C:/Selbststudium/Udemy/Udemy_Tensorflow/logs/aug_and_norm/')
if not os.path.exists(LOGS_DIR):
    os.mkdir(LOGS_DIR)
MODEL_LOG_DIR = os.path.join(LOGS_DIR, 'cnn_no_norm_no_augment')

# %%
def build_model(img_shape: Tuple[int, int, int], num_classes: int) -> Model:
    input_img = Input(shape=img_shape)

    x = Conv2D(filters=32, kernel_size=3, padding='same')(input_img)
    x = Activation('relu')(x)
    x = Conv2D(filters=32, kernel_size=3, padding='same')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(filters=64, kernel_size=3, padding='same')(x)
    x = Activation('relu')(x)
    x = Conv2D(filters=64, kernel_size=3, padding='same')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Flatten()(x)
    x = Dense(units=num_classes)(x)
    y_pred = Activation('softmax')(x)

    # Jetzt muss noch ein Modell Objekt mit eben obiger Struktur erstellt werden
    model = Model(
        inputs = [input_img],
        outputs = [y_pred]
    )

    model.summary()

    return model

# %%
data = MNIST(with_normalization=False)
# data.data_augmentation(augment_size=5_000)
x_train_, x_val_, y_train_, y_val_ = data.get_splitted_train_validation_set()
model = build_model(data.img_shape, data.num_classes)

model.compile(
    loss='categorical_crossentropy', # wird bei Kategorie-Problemen mit mehr als 2 Klassen genommen
    optimizer=Adam(learning_rate=0.0005),
    metrics=['accuracy']
)

tb_callback = TensorBoard(
    log_dir=MODEL_LOG_DIR,
    write_graph=True
)

model.fit(
    x=x_train_,
    y=y_train_,
    epochs=40,
    batch_size=128,
    verbose=1,
    validation_data=(x_val_, y_val_),
    callbacks=[tb_callback]
)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  activation (Activation)     (None, 28, 28, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        9248
#
#  activation_1 (Activation)   (None, 28, 28, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 64)        18496
#
#  activation_2 (Activation)   (None, 14, 14, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 64)        36928
#
#  activation_3 (Activation)   (None, 14, 14, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 10)                31370
#
#  activation_4 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 96,362
# Trainable params: 96,362
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 315/315 [==============================] - 6s 9ms/step - loss: 0.5053 - accuracy: 0.8975 - val_loss: 0.0970 - val_accuracy: 0.9705
# Epoch 2/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0661 - accuracy: 0.9801 - val_loss: 0.0766 - val_accuracy: 0.9770
# Epoch 3/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0413 - accuracy: 0.9877 - val_loss: 0.0595 - val_accuracy: 0.9818
# Epoch 4/40
# 315/315 [==============================] - 2s 8ms/step - loss: 0.0287 - accuracy: 0.9911 - val_loss: 0.0650 - val_accuracy: 0.9795
# Epoch 5/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0240 - accuracy: 0.9921 - val_loss: 0.0572 - val_accuracy: 0.9830
# Epoch 6/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0148 - accuracy: 0.9955 - val_loss: 0.0495 - val_accuracy: 0.9856
# Epoch 7/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0180 - accuracy: 0.9941 - val_loss: 0.0539 - val_accuracy: 0.9840
# Epoch 8/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0119 - accuracy: 0.9959 - val_loss: 0.0588 - val_accuracy: 0.9851
# Epoch 9/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0148 - accuracy: 0.9948 - val_loss: 0.0534 - val_accuracy: 0.9870
# Epoch 10/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0085 - accuracy: 0.9969 - val_loss: 0.0612 - val_accuracy: 0.9858
# Epoch 11/40
# 315/315 [==============================] - 2s 8ms/step - loss: 0.0102 - accuracy: 0.9965 - val_loss: 0.0719 - val_accuracy: 0.9837
# Epoch 12/40
# 315/315 [==============================] - 2s 8ms/step - loss: 0.0071 - accuracy: 0.9974 - val_loss: 0.0761 - val_accuracy: 0.9842
# Epoch 13/40
# 315/315 [==============================] - 2s 8ms/step - loss: 0.0092 - accuracy: 0.9968 - val_loss: 0.0945 - val_accuracy: 0.9797
# Epoch 14/40
# 315/315 [==============================] - 2s 8ms/step - loss: 0.0269 - accuracy: 0.9918 - val_loss: 0.0496 - val_accuracy: 0.9887
# Epoch 15/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0052 - accuracy: 0.9980 - val_loss: 0.0645 - val_accuracy: 0.9872
# Epoch 16/40
# 315/315 [==============================] - 2s 8ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.0634 - val_accuracy: 0.9865
# Epoch 17/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0110 - accuracy: 0.9957 - val_loss: 0.0652 - val_accuracy: 0.9865
# Epoch 18/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0079 - accuracy: 0.9971 - val_loss: 0.0553 - val_accuracy: 0.9888
# Epoch 19/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.0714 - val_accuracy: 0.9870
# Epoch 20/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.0602 - val_accuracy: 0.9880
# Epoch 21/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0072 - accuracy: 0.9978 - val_loss: 0.0523 - val_accuracy: 0.9894
# Epoch 22/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.0640 - val_accuracy: 0.9877
# Epoch 23/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.0733 - val_accuracy: 0.9866
# Epoch 24/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0076 - accuracy: 0.9977 - val_loss: 0.0601 - val_accuracy: 0.9899
# Epoch 25/40
# 315/315 [==============================] - 2s 8ms/step - loss: 0.0044 - accuracy: 0.9986 - val_loss: 0.0757 - val_accuracy: 0.9874
# Epoch 26/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.0596 - val_accuracy: 0.9903
# Epoch 27/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.0711 - val_accuracy: 0.9890
# Epoch 28/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.0623 - val_accuracy: 0.9885
# Epoch 29/40
# 315/315 [==============================] - 2s 8ms/step - loss: 0.0064 - accuracy: 0.9978 - val_loss: 0.0633 - val_accuracy: 0.9891
# Epoch 30/40
# 315/315 [==============================] - 2s 8ms/step - loss: 0.0056 - accuracy: 0.9982 - val_loss: 0.0632 - val_accuracy: 0.9892
# Epoch 31/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0677 - val_accuracy: 0.9904
# Epoch 32/40
# 315/315 [==============================] - 2s 8ms/step - loss: 6.7923e-04 - accuracy: 0.9998 - val_loss: 0.0633 - val_accuracy: 0.9912
# Epoch 33/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.0916 - val_accuracy: 0.9869
# Epoch 34/40
# 315/315 [==============================] - 2s 8ms/step - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.0640 - val_accuracy: 0.9886
# Epoch 35/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0578 - val_accuracy: 0.9908
# Epoch 36/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.0657 - val_accuracy: 0.9897
# Epoch 37/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0035 - accuracy: 0.9987 - val_loss: 0.0699 - val_accuracy: 0.9901
# Epoch 38/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.0651 - val_accuracy: 0.9902
# Epoch 39/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.0722 - val_accuracy: 0.9889
# Epoch 40/40
# 315/315 [==============================] - 2s 7ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.0784 - val_accuracy: 0.9882
