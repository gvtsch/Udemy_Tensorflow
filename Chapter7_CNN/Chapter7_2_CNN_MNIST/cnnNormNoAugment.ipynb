# %% [markdown]
# In diesem Skript wird nicht auf ein sequentielles Model (Sequential) gesetzt, sondern auf ein Model

# %%
import os # Arbeiten mit Pfaden
import numpy as np
from typing import Tuple

from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import MaxPooling2D

import matplotlib.pyplot as plt

from mnistData import MNIST
# Out:
# Train size: 60000
# Test size: 10000
# Train shape: (60000, 28, 28, 1)
# Test shape: (10000, 28, 28, 1)
# Min of x_train: 0.0
# Max of x_train: 1.0

# %%
LOGS_DIR = os.path.abspath('C:/Selbststudium/Udemy/Udemy_Tensorflow/logs/aug_and_norm/')
if not os.path.exists(LOGS_DIR):
    os.mkdir(LOGS_DIR)
MODEL_LOG_DIR = os.path.join(LOGS_DIR, 'cnn_norm_no_augment')

# %%
def build_model(img_shape: Tuple[int, int, int], num_classes: int) -> Model:
    input_img = Input(shape=img_shape)

    x = Conv2D(filters=32, kernel_size=3, padding='same')(input_img)
    x = Activation('relu')(x)
    x = Conv2D(filters=32, kernel_size=3, padding='same')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(filters=64, kernel_size=3, padding='same')(x)
    x = Activation('relu')(x)
    x = Conv2D(filters=64, kernel_size=3, padding='same')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Flatten()(x)
    x = Dense(units=num_classes)(x)
    y_pred = Activation('softmax')(x)

    # Jetzt muss noch ein Modell Objekt mit eben obiger Struktur erstellt werden
    model = Model(
        inputs = [input_img],
        outputs = [y_pred]
    )

    model.summary()

    return model

# %%
data = MNIST(with_normalization=True)
# data.data_augmentation(augment_size=5_000)
x_train_, x_val_, y_train_, y_val_ = data.get_splitted_train_validation_set()
model = build_model(data.img_shape, data.num_classes)

model.compile(
    loss='categorical_crossentropy', # wird bei Kategorie-Problemen mit mehr als 2 Klassen genommen
    optimizer=Adam(learning_rate=0.0005),
    metrics=['accuracy']
)

tb_callback = TensorBoard(
    log_dir=MODEL_LOG_DIR,
    write_graph=True
)

model.fit(
    x=x_train_,
    y=y_train_,
    epochs=40,
    batch_size=128,
    verbose=1,
    validation_data=(x_val_, y_val_),
    callbacks=[tb_callback]
)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  activation (Activation)     (None, 28, 28, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        9248
#
#  activation_1 (Activation)   (None, 28, 28, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 64)        18496
#
#  activation_2 (Activation)   (None, 14, 14, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 64)        36928
#
#  activation_3 (Activation)   (None, 14, 14, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 10)                31370
#
#  activation_4 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 96,362
# Trainable params: 96,362
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 315/315 [==============================] - 59s 12ms/step - loss: 0.3373 - accuracy: 0.8936 - val_loss: 0.0978 - val_accuracy: 0.9711
# Epoch 2/40
# 315/315 [==============================] - 3s 10ms/step - loss: 0.0784 - accuracy: 0.9761 - val_loss: 0.0707 - val_accuracy: 0.9778
# Epoch 3/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0528 - accuracy: 0.9838 - val_loss: 0.0598 - val_accuracy: 0.9809
# Epoch 4/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0382 - accuracy: 0.9878 - val_loss: 0.0533 - val_accuracy: 0.9848
# Epoch 5/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0329 - accuracy: 0.9892 - val_loss: 0.0417 - val_accuracy: 0.9870
# Epoch 6/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0258 - accuracy: 0.9911 - val_loss: 0.0436 - val_accuracy: 0.9869
# Epoch 7/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0210 - accuracy: 0.9931 - val_loss: 0.0423 - val_accuracy: 0.9887
# Epoch 8/40
# 315/315 [==============================] - 3s 8ms/step - loss: 0.0172 - accuracy: 0.9945 - val_loss: 0.0403 - val_accuracy: 0.9887
# Epoch 9/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0151 - accuracy: 0.9952 - val_loss: 0.0391 - val_accuracy: 0.9897
# Epoch 10/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0131 - accuracy: 0.9956 - val_loss: 0.0452 - val_accuracy: 0.9879
# Epoch 11/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0108 - accuracy: 0.9962 - val_loss: 0.0480 - val_accuracy: 0.9870
# Epoch 12/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.0455 - val_accuracy: 0.9891
# Epoch 13/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0083 - accuracy: 0.9969 - val_loss: 0.0554 - val_accuracy: 0.9868
# Epoch 14/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0078 - accuracy: 0.9971 - val_loss: 0.0456 - val_accuracy: 0.9899
# Epoch 15/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0052 - accuracy: 0.9980 - val_loss: 0.0530 - val_accuracy: 0.9883
# Epoch 16/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.0538 - val_accuracy: 0.9888
# Epoch 17/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.0450 - val_accuracy: 0.9905
# Epoch 18/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.0544 - val_accuracy: 0.9897
# Epoch 19/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.0546 - val_accuracy: 0.9889
# Epoch 20/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.0593 - val_accuracy: 0.9886
# Epoch 21/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.0494 - val_accuracy: 0.9912
# Epoch 22/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0586 - val_accuracy: 0.9877
# Epoch 23/40
# 315/315 [==============================] - 3s 8ms/step - loss: 0.0053 - accuracy: 0.9980 - val_loss: 0.0445 - val_accuracy: 0.9908
# Epoch 24/40
# 315/315 [==============================] - 3s 8ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0568 - val_accuracy: 0.9893
# Epoch 25/40
# 315/315 [==============================] - 3s 8ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.0545 - val_accuracy: 0.9898
# Epoch 26/40
# 315/315 [==============================] - 3s 9ms/step - loss: 7.8150e-04 - accuracy: 0.9998 - val_loss: 0.0562 - val_accuracy: 0.9916
# Epoch 27/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.0540 - val_accuracy: 0.9894
# Epoch 28/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0032 - accuracy: 0.9987 - val_loss: 0.0654 - val_accuracy: 0.9881
# Epoch 29/40
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.0587 - val_accuracy: 0.9899
# Epoch 30/40
# 315/315 [==============================] - 3s 8ms/step - loss: 0.0037 - accuracy: 0.9987 - val_loss: 0.0576 - val_accuracy: 0.9904
# Epoch 31/40
# 315/315 [==============================] - 3s 8ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.0585 - val_accuracy: 0.9906
# Epoch 32/40
# 315/315 [==============================] - 3s 8ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0632 - val_accuracy: 0.9904
# Epoch 33/40
# 315/315 [==============================] - 3s 9ms/step - loss: 8.7448e-04 - accuracy: 0.9997 - val_loss: 0.0595 - val_accuracy: 0.9916
# Epoch 34/40
# 315/315 [==============================] - 3s 8ms/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 0.0535 - val_accuracy: 0.9893
# Epoch 35/40
# 315/315 [==============================] - 3s 8ms/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.0533 - val_accuracy: 0.9917
# Epoch 36/40
# 315/315 [==============================] - 3s 8ms/step - loss: 2.5543e-04 - accuracy: 1.0000 - val_loss: 0.0581 - val_accuracy: 0.9915
# Epoch 37/40
# 315/315 [==============================] - 3s 8ms/step - loss: 1.5689e-04 - accuracy: 1.0000 - val_loss: 0.0596 - val_accuracy: 0.9917
# Epoch 38/40
# 315/315 [==============================] - 3s 8ms/step - loss: 2.3404e-05 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 0.9919
# Epoch 39/40
# 315/315 [==============================] - 3s 8ms/step - loss: 1.2786e-05 - accuracy: 1.0000 - val_loss: 0.0616 - val_accuracy: 0.9919
# Epoch 40/40
# 315/315 [==============================] - 3s 8ms/step - loss: 9.3510e-06 - accuracy: 1.0000 - val_loss: 0.0626 - val_accuracy: 0.9920
