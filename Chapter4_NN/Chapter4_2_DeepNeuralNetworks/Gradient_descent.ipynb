# %%
import numpy as np

from helper import f
from helper import f_prime_x0
from helper import f_prime_x1
from helper import plot_rosenbrock

# %%
np.random.seed(0)

# %%
def main():
    x0 = np.random.uniform(-2.0, 2.0)
    x1 = np.random.uniform(-2.0, 2.0)

    x_start = (x0, x1)
    y_start = f(x0, x1)

    print(f'Global minimum: {(1, 1)}')
    print(f'x_start: {x_start}')
    print(f'y_start: {y_start}')
    plot_rosenbrock

    learning_rate = 0.005
    num_iterations = 1_000

    gradient_steps = []

    for it in range(num_iterations):
        x0 = x0 - f_prime_x0(x0, x1) * learning_rate
        x1 = x1 - f_prime_x1(x0, x1) * learning_rate
        y = f(x0, x1)
        if it % 10 == 0:
            print(f'x0, x1 = {(x0, x1)}, y = {y}')
            gradient_steps.append((x0, x1))

    x_end = (x0, x1)
    y_end = f(x0, x1)

    print(f'x0 end, x1 end = {(x0, x1)}, y end = {y}')
    plot_rosenbrock(x_start, gradient_steps)

# %%
if __name__=='__main__':
    main()
# Out:
# Global minimum: (1, 1)
# x_start: (0.195254015709299, 0.8607574654896779)
# y_start: 68.32017645807709
# x0, x1 = (0.5245463997195279, 0.2751489254587187), y = 0.22605612601966296
# x0, x1 = (0.5700082864079399, 0.324909446573716), y = 0.18489287375783625
# x0, x1 = (0.6111232018250211, 0.3734715678088655), y = 0.15122516415882326
# x0, x1 = (0.6483067943437325, 0.42030169959224667), y = 0.12368811090478166
# x0, x1 = (0.6819349689020865, 0.46503530181148967), y = 0.10116536400731668
# x0, x1 = (0.7123476871879291, 0.5074392274419917), y = 0.08274385306613351
# x0, x1 = (0.7398524044579377, 0.5473815803821918), y = 0.06767677146631645
# x0, x1 = (0.7647271777351183, 0.5848076563667193), y = 0.0553533008964826
# x0, x1 = (0.7872234768069087, 0.6197208024359576), y = 0.045273848822140104
# x0, x1 = (0.8075687264414732, 0.6521672479263029), y = 0.03702979504335659
# x0, x1 = (0.8259686055225526, 0.6822241373088701), y = 0.03028692626376492
# x0, x1 = (0.8426091263458104, 0.7099901398012499), y = 0.024771887109629066
# x0, x1 = (0.8576585150971754, 0.7355781285186919), y = 0.020261098324341045
# x0, x1 = (0.8712689125237489, 0.7591095179303161), y = 0.016571692882818203
# x0, x1 = (0.8835779119900881, 0.7807099265567639), y = 0.01355410257658768
# x0, x1 = (0.8947099504687381, 0.8005058954677718), y = 0.011085994530295577
# x0, x1 = (0.9047775665271374, 0.8186224448907685), y = 0.00906731183649375
# x0, x1 = (0.9138825380284247, 0.8351812933132751), y = 0.007416217256425723
# x0, x1 = (0.922116911047655, 0.8502995976400689), y = 0.006065775544758879
# x0, x1 = (0.929563930405183, 0.864089100710332), y = 0.004961239899965899
# x0, x1 = (0.9362988812243748, 0.8766555949820158), y = 0.004057832533266314
# x0, x1 = (0.9423898500213177, 0.8880986294232016), y = 0.003318929380566268
# x0, x1 = (0.9478984130207109, 0.8985114014071822), y = 0.0027145753657604305
# x0, x1 = (0.9528802586564188, 0.9079807873371236), y = 0.0022202700242859967
# x0, x1 = (0.9573857505498138, 0.9165874753558303), y = 0.0018159742562026961
# x0, x1 = (0.9614604366572979, 0.9244061712572419), y = 0.0014852979426461508
# x0, x1 = (0.9651455097341938, 0.9315058549600768), y = 0.001214835491689181
# x0, x1 = (0.968478223770036, 0.9379500699167639), y = 0.000993622376691923
# x0, x1 = (0.9714922706051818, 0.9437972318456118), y = 0.0008126906352481794
# x0, x1 = (0.9742181205361249, 0.9491009463809396), y = 0.0006647053086897852
# x0, x1 = (0.9766833303528336, 0.9539103277891023), y = 0.0005436670834350904
# x0, x1 = (0.9789128219222009, 0.9582703129236866), y = 0.0004446690792848126
# x0, x1 = (0.9809291341339199, 0.9622219661927218), y = 0.00036369792488201864
# x0, x1 = (0.9827526507558201, 0.9658027725675908), y = 0.00029747105595071373
# x0, x1 = (0.9844018065021469, 0.9690469166446903), y = 0.00024330364039646594
# x0, x1 = (0.9858932733980228, 0.9719855465314685), y = 0.00019899973542293132
# x0, x1 = (0.987242129324122, 0.9746470219124265), y = 0.00016276326418242698
# x0, x1 = (0.9884620104454553, 0.9770571460938715), y = 0.00013312520296078164
# x0, x1 = (0.9895652490652309, 0.9792393821575325), y = 0.00010888402707066436
# x0, x1 = (0.9905629982974135, 0.9812150535959615), y = 8.905700113462135e-05
# x0, x1 = (0.991465344818353, 0.9830035299757757), y = 7.28403390696136e-05
# x0, x1 = (0.9922814108373376, 0.9846223982933371), y = 5.957661866197002e-05
# x0, x1 = (0.9930194463169308, 0.9860876207635839), y = 4.8728129722210375e-05
# x0, x1 = (0.9936869123753957, 0.9874136798261475), y = 3.985507535593136e-05
# x0, x1 = (0.994290556714348, 0.988613711171328), y = 3.2597742632077144e-05
# x0, x1 = (0.994836481834177, 0.9896996255882029), y = 2.6661919848783546e-05
# x0, x1 = (0.9953302067268472, 0.9906822204229084), y = 2.180696921398273e-05
# x0, x1 = (0.9957767226697638, 0.9915712814109356), y = 1.783607140808698e-05
# x0, x1 = (0.9961805436847435, 0.9923756756160311), y = 1.4588246544152657e-05
# x0, x1 = (0.9965457521722028, 0.9931034361724613), y = 1.1931828055841958e-05
# x0, x1 = (0.9968760401819021, 0.9937618394887493), y = 9.75912494509012e-06
# x0, x1 = (0.9971747467374645, 0.9943574755309266), y = 7.982055997467291e-06
# x0, x1 = (0.997444891592003, 0.9948963117629827), y = 6.528578976616952e-06
# x0, x1 = (0.9976892057561032, 0.995383751282244), y = 5.339770037626568e-06
# x0, x1 = (0.9979101591067863, 0.9958246856485314), y = 4.36743495894838e-06
# x0, x1 = (0.998109985356557, 0.9962235428684665), y = 3.572155352428823e-06
# x0, x1 = (0.998290704634966, 0.9965843309605771), y = 2.9216906449265345e-06
# x0, x1 = (0.9984541439109678, 0.9969106774929836), y = 2.389671047998047e-06
# x0, x1 = (0.998601955462536, 0.9972058654536008), y = 1.9545285287327883e-06
# x0, x1 = (0.9987356335802536, 0.9974728657829507), y = 1.5986224433822427e-06
# x0, x1 = (0.9988565296737383, 0.9977143668718637), y = 1.3075243870410835e-06
# x0, x1 = (0.9989658659336245, 0.9979328013005162), y = 1.0694332672384016e-06
# x0, x1 = (0.999064747687214, 0.9981303700713166), y = 8.746968885715935e-07
# x0, x1 = (0.9991541745727057, 0.9983090645660649), y = 7.154206534575476e-07
# x0, x1 = (0.9992350506449683, 0.9984706864374524), y = 5.851475157633916e-07
# x0, x1 = (0.9993081935150201, 0.9986168656262528), y = 4.785962126602537e-07
# x0, x1 = (0.9993743426156093, 0.9987490766783813), y = 3.914471626425967e-07
# x0, x1 = (0.9994341666764602, 0.9988686535202705), y = 3.2016735002805766e-07
# x0, x1 = (0.9994882704847481, 0.998976802836593), y = 2.618670967799579e-07
# x0, x1 = (0.9995372009991532, 0.9990746161812216), y = 2.1418291518477864e-07
# x0, x1 = (0.9995814528793021, 0.9991630809402965), y = 1.7518169224449197e-07
# x0, x1 = (0.9996214734864943, 0.9992430902553101), y = 1.432823214267601e-07
# x0, x1 = (0.9996576674062697, 0.9993154520041442), y = 1.1719160473010635e-07
# x0, x1 = (0.9996904005385389, 0.9993808969289043), y = 9.585182653702841e-08
# x0, x1 = (0.9997200037966223, 0.9994400859911184), y = 7.83978739059309e-08
# x0, x1 = (0.9997467764525948, 0.9994936170273545), y = 6.412216496047427e-08
# x0, x1 = (0.9997709891627565, 0.9995420307714766), y = 5.244596357495543e-08
# x0, x1 = (0.9997928867038142, 0.9995858163035458), y = 4.289591745696126e-08
# x0, x1 = (0.9998126904474335, 0.9996254159797354), y = 3.508486848266877e-08
# x0, x1 = (0.9998306005981811, 0.9996612298925195), y = 2.8696157336609945e-08
# x0, x1 = (0.9998467982174778, 0.9996936199057418), y = 2.347078616798112e-08
# x0, x1 = (0.9998614470540274, 0.9997229133049735), y = 1.9196918837699392e-08
# x0, x1 = (0.9998746951992227, 0.9997494060997384), y = 1.5701293097845382e-08
# x0, x1 = (0.9998866765842643, 0.9997733660107252), y = 1.2842196553998734e-08
# x0, x1 = (0.99989751233413, 0.9997950351719818), y = 1.0503721655471483e-08
# x0, x1 = (0.9999073119920778, 0.9998146325752225), y = 8.591066812580314e-09
# x0, x1 = (0.999916174627067, 0.999832356280827), y = 7.0266931473657735e-09
# x0, x1 = (0.9999241898352884, 0.9998483854177579), y = 5.74718107359798e-09
# x0, x1 = (0.9999314386459315, 0.9998628819925223), y = 4.700659271708863e-09
# x0, x1 = (0.9999379943403418, 0.9998759925253854), y = 3.8447018296476685e-09
# x0, x1 = (0.9999439231928562, 0.9998878495303207), y = 3.1446082994443123e-09
# x0, x1 = (0.9999492851407954, 0.9998985728535877), y = 2.5719969441427677e-09
# x0, x1 = (0.9999541343903986, 0.9999082708844513), y = 2.1036541441083275e-09
# x0, x1 = (0.9999585199648172, 0.9999170416502278), y = 1.7205933187649785e-09
# x0, x1 = (0.99996248619971, 0.9999249738067051), y = 1.4072852122014159e-09
# x0, x1 = (0.9999660731914523, 0.9999321475339329), y = 1.1510283382354254e-09
# x0, x1 = (0.9999693172024873, 0.9999386353464086), y = 9.41434063206983e-10
# x0, x1 = (0.9999722510279183, 0.9999445028258421), y = 7.700054515902462e-10
# x0, x1 = (0.9999749043270494, 0.9999498092838915), y = 6.297928008442121e-10
# x0, x1 = (0.9999773039232231, 0.9999546083615583), y = 5.151119010607321e-10
# x0 end, x1 end = (0.9999792667424141, 0.9999585339146961), y end = 4.298679701229507e-10
